# %% [markdown]
# # Museums in the Pandemic - Indicator matching validation
# **Authors**: Andrea Ballatore (KCL)
#
# **Abstract**: Validation of matching process of indicators in text.
#
# ## Setup
# This is to check that your environment is set up correctly (it should print 'env ok', ignore warnings).

# %%
# Test geospatial libraries
# check environment
import os
print("Conda env:", os.environ['CONDA_DEFAULT_ENV'])
if os.environ['CONDA_DEFAULT_ENV'] != 'mip_v1':
    raise Exception("Set the environment 'mip_v1' on Anaconda. Current environment: " + os.environ['CONDA_DEFAULT_ENV'])

# spatial libraries 
import pandas as pd
import pickle
from termcolor import colored
import sys
import spacy
import numpy as np
from numpy import arange
#import tensorflow as tf
from bs4 import BeautifulSoup
from bs4.element import Comment
#import torch
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# import from `mip` project
print(os.getcwd())
fpath = os.path.abspath('../')
if not fpath in sys.path:
    sys.path.insert(0, fpath)

out_folder = '../../'

from museums import *
from utils import _is_number
from analytics.text_models import derive_new_attributes_matches, get_all_matches_from_db

print('env ok')
# Out:
# Conda env: mip_v1
# /Users/andreaballatore/Dropbox/DRBX_Docs/Work/Projects/github_projects/museums-in-the-pandemic/mip/notebooks
# env ok

# %% [markdown]
# ## Connect to DB
#
# It needs the DCS VPN active to work.

# %%
# open connection to DB
from db.db import connect_to_postgresql_db

db_conn = connect_to_postgresql_db()
print("DB connected")
# Out:
# DB connected

# %% [markdown]
# ## Setup spacy NLP

# %%
# install language model
# !python -m spacy download en_core_web_lg
# Note: if this cell does not work, run the same command 
#       without "!" in the Anaconda terminal
# Out:
# Collecting en_core_web_lg==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.3.1/en_core_web_lg-2.3.1.tar.gz (782.7 MB)
#      |▊                               | 17.0 MB 3.3 MB/s eta 0:03:50^C
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 75, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 471, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 433, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 295, in __init__
#     super().__init__(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/network/download.py", line 145, in __call__
#     for chunk in chunks:
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 148, in iter
#     self.next(len(x))  # noqa: B305
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_vendor/progress/__init__.py", line 120, in next
#     self.update()
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_vendor/progress/bar.py", line 83, in update
#     self.writeln(line)
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_vendor/progress/__init__.py", line 103, in writeln
#     self.file.flush()
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 103, in handle_sigint
#     self.finish()
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 93, in finish
#     super().finish()  # type: ignore
#   File "/Users/andreaballatore/opt/anaconda3/envs/mip_v1/lib/python3.8/site-packages/pip/_vendor/progress/__init__.py", line 107, in finish
#     print(file=self.file)
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>

# %%
# set up the spacy environment
import spacy
from spacy import displacy
from collections import Counter
spacy.prefer_gpu()
# load language model
import en_core_web_lg
nlp = en_core_web_lg.load()

# %%
# Spacy stopwords
#all_stopwords = nlp.Defaults.stop_words

# %%
# get text from websites

from analytics.an_websites import get_attribute_for_webpage_url

session_id = '20210420'
test_urls = ['https://www.britishmuseum.org/']
attrib_name = 'all_text' # 'title'

for url in test_urls:
    print(url)
    res = get_attribute_for_webpage_url(url, session_id, attrib_name, db_conn)
    if not res: continue
    print(res)
    blocks = res.split("\n")
    print("LEN", len(blocks))
    print(blocks)
# Out:
# https://www.britishmuseum.org/
# Skip to main content Please enable JavaScript in your web browser to get the best experience. We use cookies to make our website work more efficiently, to provide you with more personalised services or advertising to you, and to analyse traffic on our website. For more information on how we use cookies and how to manage cookies, please follow the 'Read more' link, otherwise select 'Accept and close'. Read more about our cookie policy Accept and close the cookie policy Menu Main navigation Visit Toggle Visit submenu Back
# to previous menu —
# Visit —
# Visit —
# Family visits —
# Group visits —
# Audio guide —
# Out-of-hours tours —
# Tours and talks —
# Object trails —
# Accessibility —
# Food and drink —
# Late opening on Fridays —
# Museum map Exhibitions and events Collection Toggle Collection submenu Back
# to previous menu —
# Collection —
# Collection —
# Collection online —
# Galleries —
# Blog —
# Audio tour highlights —
# The British Museum podcast Learn Toggle Learn submenu Back
# to previous menu —
# Learn —
# Learn —
# Schools —
# Communities —
# Adult learning —
# Young people Membership Toggle Membership submenu Back
# to previous menu —
# Membership —
# Membership —
# Renew Membership —
# Events —
# Buy Membership —
# Renew Gift Membership —
# Existing Members —
# Buy Under 26 Membership —
# Upgrade your Membership —
# How your money helps —
# Buy Gift Membership —
# Visiting as a Member —
# Members' Room Support us Toggle Support us submenu Back
# to previous menu —
# Support us —
# Donate —
# Corporate support —
# Become a Patron —
# Supporter case studies —
# Become a Volunteer —
# Leave a legacy —
# American Friends of the British Museum Secondary navigation Shop Search Donate Hide menu The British Museum Stay connected We're planning to reopen in May – until then you can explore the Museum online. Find out more Show image caption Close image caption The Great Court at the British Museum. Explore the Great Court Discover two million years of human history and culture Free entry The Museum is closed Exhibitions and events See all exhibitions and events Thomas Becket murder and the making of a saint . Coming soon
# . Exhibition Coming soon Reflections
# contemporary art of the Middle East and North Africa . Coming soon
# . Exhibition Coming soon We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations. More ways to enjoy the Museum from home Take a virtual gallery tour Explore the Museum's galleries from home and get closer to the collection, using Google Street View. Fill your bookshelves this spring Dive into a new novel, brush up on your history or leaf through exhibition catalogues in our online bookshop. Objects in 3D See some of our most popular objects from every angle on Sketchfab, including mummy masks and the Rosetta Stone. Traverse our object timeline From ancient handaxes to a penny defaced by suffragettes, travel through thousands of years of history in an audio tour of popular objects. Sign up to our newsletters Stay connected and receive all our latest news, online events and ways to visit the Museum from home. Sign up Support the Museum Become a Member Support us by becoming a Member today and get 10% off in our online shop. Donate Your support is vital and helps the Museum to share the collection with the world. Shop online The British Museum shop has a range of unique gifts, replicas, games and more. 10% off for Members Become a Member and enjoy a 10% discount at all of the Museum's shops. Visit the online shop Explore the collection See all Egypt Read more Desire, love and identity Read the blog Animals See the collection Americas See the collection Death and memory Read more Africa See the collection Welcome to the British Museum Shop Shop now Inspired by the Museum https://www.britishmuseumshoponline.org/inspired-by/inspired-by-the-british-mus... Inspired by the Lewis Chessmen https://www.britishmuseumshoponline.org/inspired-by/lewis-chessmen-collection.h... Inspired by Sutton Hoo https://www.britishmuseumshoponline.org/inspired-by/sutton-hoo.html Inspired by London https://www.britishmuseumshoponline.org/inspired-by/inspired-by-london.html Inspired by cats https://www.britishmuseumshoponline.org/inspired-by/inspired-by-cats.html Inspired by Hokusai https://www.britishmuseumshoponline.org/inspired-by/inspired-by-hokusai.html Inspired by ancient Egypt https://www.britishmuseumshoponline.org/inspired-by/ancient-egypt.html Connect with us Enter your email address to receive our newsletter Facebook Twitter Instagram Youtube weibo wechat . Opens a pop-up detailing how to access wechat. Close wechat Scan the QR code to be taken to WeChat. Back to the top Free entry Great Russell Street
# London WC1B 3DG +44 (0)20 7323 8000 Opening hours The Museum is closed. Footer About us Governance The British Museum story Jobs Press Contact us Visit Museum map Exhibitions and events Accessibility Food and drink Audio guide Commercial Commercial hire Filming Travel trade tours British Museum Press BM Images Our work Departments National International How to borrow Research Research projects Research publications Scientific studies Resources Study rooms Library and archive Search the collection Blog Footer Legal Links Privacy policy Cookies Accessibility Statement Terms of use Modern Slavery Act Statement Chinese site 中文 © 2021
# The Trustees of the British Museum
# LEN 57
# ["Skip to main content Please enable JavaScript in your web browser to get the best experience. We use cookies to make our website work more efficiently, to provide you with more personalised services or advertising to you, and to analyse traffic on our website. For more information on how we use cookies and how to manage cookies, please follow the 'Read more' link, otherwise select 'Accept and close'. Read more about our cookie policy Accept and close the cookie policy Menu Main navigation Visit Toggle Visit submenu Back", 'to previous menu —', 'Visit —', 'Visit —', 'Family visits —', 'Group visits —', 'Audio guide —', 'Out-of-hours tours —', 'Tours and talks —', 'Object trails —', 'Accessibility —', 'Food and drink —', 'Late opening on Fridays —', 'Museum map Exhibitions and events Collection Toggle Collection submenu Back', 'to previous menu —', 'Collection —', 'Collection —', 'Collection online —', 'Galleries —', 'Blog —', 'Audio tour highlights —', 'The British Museum podcast Learn Toggle Learn submenu Back', 'to previous menu —', 'Learn —', 'Learn —', 'Schools —', 'Communities —', 'Adult learning —', 'Young people Membership Toggle Membership submenu Back', 'to previous menu —', 'Membership —', 'Membership —', 'Renew Membership —', 'Events —', 'Buy Membership —', 'Renew Gift Membership —', 'Existing Members —', 'Buy Under 26 Membership —', 'Upgrade your Membership —', 'How your money helps —', 'Buy Gift Membership —', 'Visiting as a Member —', "Members' Room Support us Toggle Support us submenu Back", 'to previous menu —', 'Support us —', 'Donate —', 'Corporate support —', 'Become a Patron —', 'Supporter case studies —', 'Become a Volunteer —', 'Leave a legacy —', "American Friends of the British Museum Secondary navigation Shop Search Donate Hide menu The British Museum Stay connected We're planning to reopen in May – until then you can explore the Museum online. Find out more Show image caption Close image caption The Great Court at the British Museum. Explore the Great Court Discover two million years of human history and culture Free entry The Museum is closed Exhibitions and events See all exhibitions and events Thomas Becket murder and the making of a saint . Coming soon", '. Exhibition Coming soon Reflections', 'contemporary art of the Middle East and North Africa . Coming soon', ". Exhibition Coming soon We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations. More ways to enjoy the Museum from home Take a virtual gallery tour Explore the Museum's galleries from home and get closer to the collection, using Google Street View. Fill your bookshelves this spring Dive into a new novel, brush up on your history or leaf through exhibition catalogues in our online bookshop. Objects in 3D See some of our most popular objects from every angle on Sketchfab, including mummy masks and the Rosetta Stone. Traverse our object timeline From ancient handaxes to a penny defaced by suffragettes, travel through thousands of years of history in an audio tour of popular objects. Sign up to our newsletters Stay connected and receive all our latest news, online events and ways to visit the Museum from home. Sign up Support the Museum Become a Member Support us by becoming a Member today and get 10% off in our onlin ...

# %% [markdown]
# ## Annotations
#
# These are manually created annotations (identified by the *example_id*) to identify indicators in the text.

# %%
# extract tokens from annotations
from analytics.text_models import get_indicator_annotations

indic_df, ann_df = get_indicator_annotations("../../")
ann_df
# Out:
#        example_id                                       text_phrases  \
# 1    ann_ex_00002  closed to members of the public until further ...
# 2    ann_ex_00003                       closed until further notice
# 5    ann_ex_00006  currently we are closed due to Covid restricti...
# 6    ann_ex_00007                                 had to close doors
# 10   ann_ex_00011  there will be no services over due to the Covi...
# ..            ...                                                ...
# 273  ann_ex_00274  Our volunteer coordinator will be in touch wit...
# 274  ann_ex_00275         please contact the museum for information
# 275  ann_ex_00276             If you have any queries please contact
# 276  ann_ex_00277                          We are continuing to work
# 277  ann_ex_00278             our shop will be offering online sales
#
#       indicator_code possible_supercategory         critical_words  \
# 1         closed_cur                    NaN  closed further notice
# 2         closed_cur                    NaN  closed further notice
# 5         closed_cur                    NaN           closed covid
# 6         closed_cur                    NaN            close doors
# 10        closed_cur                    NaN            no services
# ..               ...                    ...                    ...
# 273    staff_working                    NaN               in touch
# 274    staff_working                    NaN         contact museum
# 275    staff_working                    NaN        queries contact
# 276    staff_working                    NaN        continuing work
# 277  open_onlineshop        Online activity            online shop
#
#     valid_annotation
# 1                NaN
# 2                NaN
# 5                NaN
# 6                NaN
# 10               NaN
# ..               ...
# 273              NaN
# 274              NaN
# 275              NaN
# 276              NaN
# 277              NaN
#
# [242 rows x 6 columns]

# %%
# this is to debug the token extraction from the annotations.

ann_tokens_df = pd.DataFrame()

for index, row in ann_df.iterrows():
    txt = str(row['text_phrases']).strip()
    df = spacy_extract_tokens(txt)
    #print(df)
    df['example_id'] = row['example_id']
    df['indicator_code'] = row['indicator_code']
    ann_tokens_df = pd.concat([ann_tokens_df, df])

# output annotations tokens
fout = out_folder+'tmp/test_annotations_tokens.csv'
ann_tokens_df.to_csv(fout, index=False)
print(fout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/2142503126.py in <module>
#       5 for index, row in ann_df.iterrows():
#       6     txt = str(row['text_phrases']).strip()
# ----> 7     df = spacy_extract_tokens(txt)
#       8     #print(df)
#       9     df['example_id'] = row['example_id']
#
# NameError: name 'spacy_extract_tokens' is not defined

# %% [markdown]
# ## Indicator matching
#
# This code identifies indicators in raw text

# %%
ftext = out_folder+'tmp/museum_text_tokens.csv'
text_df = pd.read_csv(ftext)
print(len(text_df))
text_df.sample(10)

findic = out_folder+'tmp/test_annotations_tokens.csv'
ann_df = pd.read_csv(findic)
print(len(ann_df))

ann_df

# %% [markdown]
# Options for matches
# - Case sensitive/insens (lower case)
# - match lemma
# - match token
# - stopwords or not

# %%
print(text_df.columns)
print(ann_df.columns)

# %%
# call test match 
muse_id = 'test.123'
df = match_musetext_indicators(muse_id, text_df, ann_df)

print(len(df))
fout = out_folder + 'tmp/all_matches_test.csv'
df.to_csv(fout, index=False)

# %%
# a test query to the DB
assert db_conn

t = "analytics.text_indic_ann_matches"
sql = """select count(distinct muse_id) from {} t;""".format(t)
print(sql)
df = pd.read_sql(sql, db_conn)
df

# %%
# get sample of matches museums
sample_df = mus_df.sample(10)
muse_ids = sample_df.muse_id.tolist()
muse_ids = str(muse_ids).replace('[','(').replace(']',')')
#print(muse_ids)
sql = """select * from {} t where muse_id in {};""".format(t, muse_ids)
print(sql)
df = pd.read_sql(sql, db_conn)

fn = out_folder + 'tmp/match_samples.tsv'
print(df.keep_stopwords.describe())
df.to_csv(fn, sep='\t', index=False)
df.describe().transpose()
df.columns

# %% [markdown]
# ## Download matches from DB

# %%
# dump all matches from DB to a pickle file (SLOW)
sessions = ['20210304'] #,'20210404']
for session_id in sessions:
    get_all_matches_from_db(session_id, db_conn, out_folder)
# Out:
# get_all_matches_from_db 20210304
# query results: (1136440, 17)
# 	saved ../../tmp/matches_dump_df_20210304.pik

# %% [markdown]
# ## Load matches from pik
#
# `matches_dump_df_v1.pik` is used for Eval data v1, and v2 for Eval data v2 (with critical words).
#
# Eval v3 contains semantic similarity and a better sample.

# %%
# select which matches dataset to load

#matches_fn = out_folder+'tmp/matches_dump_df_v1.pik'
#matches_fn = out_folder+'tmp/matches_dump_df_v2.pik'
matches_fn = out_folder+'tmp/matches_dump_df_20210304-v3.pik'
df = pd.read_pickle(matches_fn)
print(df.columns)
df = df.drop_duplicates(subset=['session_id','muse_id','example_id','page_tokens',
        'ann_overlap_criticwords','indicator_code','ann_overlap_tokenlemma','sem_similarity'])
print(df.shape)
# Out:
# Index(['muse_id', 'page_id', 'sentence_id', 'example_id', 'indicator_code',
#        'session_id', 'ann_ex_tokens', 'page_tokens', 'sem_similarity',
#        'token_n', 'lemma_n', 'ann_overlap_lemma', 'ann_overlap_token',
#        'example_len', 'txt_overlap_lemma', 'txt_overlap_token',
#        'ann_overlap_criticwords', 'lemmatoken_n', 'ann_overlap_tokenlemma',
#        'txt_overlap_tokenlemma', 'indicator_code_closed_indef',
#        'indicator_code_closed_perm', 'indicator_code_finance_health',
#        'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working'],
#       dtype='object')
# (926924, 41)

# %% [markdown]
# ## Descriptive stats
#
# Describe the full matches dataset from the DB (800K entries for 400 museums).
#
# ### Match distributions

# %%
# descriptive stats of all values
#df.groupby('keep_stopwords').describe().transpose()
df.describe().transpose()
# Out:
#                                        count           mean            std  \
# page_id                             889212.0  460833.790326  279330.646375
# sem_similarity                      889212.0       0.704423       0.113949
# token_n                             889212.0       0.993193       0.777993
# lemma_n                             889212.0       1.283595       0.628839
# ann_overlap_lemma                   889212.0       0.259310       0.149572
# ann_overlap_token                   889212.0       0.196367       0.170579
# example_len                         889212.0       5.942764       2.928122
# txt_overlap_lemma                   889212.0       0.149241       0.102856
# txt_overlap_token                   889212.0       0.115055       0.111537
# ann_overlap_criticwords             889212.0       0.515921       0.174369
# lemmatoken_n                        889212.0       1.287045       0.632947
# ann_overlap_tokenlemma              889212.0       0.260057       0.150677
# txt_overlap_tokenlemma              889212.0       0.149597       0.103258
# indicator_code_closed_indef         889212.0       0.040165       0.196346
# indicator_code_closed_perm          889212.0       0.012202       0.109786
# indicator_code_finance_health       889212.0       0.009019       0.094540
# indicator_code_funding_did_not_get  889212.0       0.030226       0.171208
# indicator_code_funding_fundraise    889212.0       0.140714       0.347727
# indicator_code_funding_gov_emer     889212.0       0.057866       0.233490
# indicator_code_funding_other_emer   889212.0       0.008930       0.094078
# indicator_code_lang_difficulty      889212.0       0.075393       0.264024
# indicator_code_made_covid_safe      889212.0       0.012856       0.112655
# indicator_code_online_engag         889212.0       0.030909       0.173072
# indicator_code_online_event         889212.0       0.041989       0.200564
# indicator_code_online_exhib         889212.0       0.039179       0.194020
# indicator_code_open_cafe            889212.0       0.007046       0.083642
# indicator_code_open_cur             889212.0       0.045207       0.207759
# indicator_code_open_onlineshop      889212.0       0.055718       0.229376
# indicator_code_project_postpone     889212.0       0.006920       0.082896
# indicator_code_reopen_intent        889212.0       0.168080       0.373938
# indicator_code_reopen_plan          889212.0       0.015463       0.123386
# indicator_code_staff_hiring         889212.0       0.018477       0.134669
# indicator_code_staff_restruct       889212.0       0.000004       0.002121
# indicator_code_staff_working        889212.0       0.051930       0.221886
#
#                                           min            25%           50%  \
# page_id                             26.000000  229363.000000  447911.00000
# sem_similarity                      -0.109400       0.637500       0.71550
# token_n                              0.000000       1.000000       1.00000
# lemma_n                              1.000000       1.000000       1.00000
# ann_overlap_lemma                    0.058820       0.166670       0.23077
# ann_overlap_token                    0.000000       0.083330       0.16667
# example_len                          2.000000       4.000000       5.00000
# txt_overlap_lemma                    0.005650       0.076920       0.12500
# txt_overlap_token                    0.000000       0.035710       0.09091
# ann_overlap_criticwords              0.250000       0.500000       0.50000
# lemmatoken_n                         1.000000       1.000000       1.00000
# ann_overlap_tokenlemma               0.058824       0.166667       0.25000
# txt_overlap_tokenlemma               0.005650       0.076920       0.12500
# indicator_code_closed_indef          0.000000       0.000000       0.00000
# indicator_code_closed_perm           0.000000       0.000000       0.00000
# indicator_code_finance_health        0.000000       0.000000       0.00000
# indicator_code_funding_did_not_get   0.000000       0.000000       0.00000
# indicator_code_funding_fundraise     0.000000       0.000000       0.00000
# indicator_code_funding_gov_emer      0.000000       0.000000       0.00000
# indicator_code_funding_other_emer    0.000000       0.000000       0.00000
# indicator_code_lang_difficulty       0.000000       0.000000       0.00000
# indicator_code_made_covid_safe       0.000000       0.000000       0.00000
# indicator_code_online_engag          0.000000       0.000000       0.00000
# indicator_code_online_event          0.000000       0.000000       0.00000
# indicator_code_online_exhib          0.000000       0.000000       0.00000
# indicator_code_open_cafe             0.000000       0.000000       0.00000
# indicator_code_open_cur              0.000000       0.000000       0.00000
# indicator_code_open_onlineshop       0.000000       0.000000       0.00000
# indicator_code_project_postpone      0.000000       0.000000       0.00000
# indicator_code_reopen_intent         0.000000       0.000000       0.00000
# indicator_code_reopen_plan           0.000000       0.000000       0.00000
# indicator_code_staff_hiring          0.000000       0.000000       0.00000
# indicator_code_staff_restruct        0.000000       0.000000       0.00000
# indicator_code_staff_working         0.000000       0.000000       0.00000
#
#                                               75%        max
# page_id                             690467.000000  1084312.0
# sem_similarity                           0.785300        1.0
# token_n                                  1.000000       13.0
# lemma_n                                  1.000000       13.0
# ann_overlap_lemma                        0.333330        1.0
# ann_overlap_token                        0.250000        1.0
# example_len                              7.000000       17.0
# txt_overlap_lemma                        0.200000        1.0
# txt_overlap_token                        0.166670        1.0
# ann_overlap_criticwords                  0.500000        1.0
# lemmatoken_n                             1.000000       13.0
# ann_overlap_tokenlemma                   0.333333        1.0
# txt_overlap_tokenlemma                   0.200000        1.0
# indicator_code_closed_indef              0.000000        1.0
# indicator_code_closed_perm               0.000000        1.0
# indicator_code_finance_health            0.000000        1.0
# indicator_code_funding_did_not_get       0.000000        1.0
# indicator_code_funding_fundraise         0.000000        1.0
# indicator_code_funding_gov_emer          0.000000        1.0
# indicator_code_funding_other_emer        0.000000        1.0
# indicator_code_lang_difficulty           0.000000        1.0
# indicator_code_made_covid_safe           0.000000        1.0
# indicator_code_online_engag              0.000000        1.0
# indicator_code_online_event              0.000000        1.0
# indicator_code_online_exhib              0.000000        1.0
# indicator_code_open_cafe                 0.000000        1.0
# indicator_code_open_cur                  0.000000        1.0
# indicator_code_open_onlineshop           0.000000        1.0
# indicator_code_project_postpone          0.000000        1.0
# indicator_code_reopen_intent             0.000000        1.0
# indicator_code_reopen_plan               0.000000        1.0
# indicator_code_staff_hiring              0.000000        1.0
# indicator_code_staff_restruct            0.000000        1.0
# indicator_code_staff_working             0.000000        1.0

# %% [markdown]
# ### Indicator stats

# %%
# describe indicators
indic_df = round(df['indicator_code'].value_counts(normalize=True)*100,1)
indic_df.columns = ['n_matches']
indic_df.to_csv(out_folder + 'tmp/indicator_stats.csv')
print('N matches =',len(df))
indic_df

# %%
# distribution token_n and lemma_n
print(df[['token_n','lemma_n','lemmatoken_n']].describe().transpose())
df[['token_n','lemma_n','lemmatoken_n']].hist(bins=10)

# %%
# histogram of number of matched lemma/token
df[['lemmatoken_n']].hist(bins=10)

# %%
# exclude matches of a single lemma 
print(df[['lemma_n']][df.lemma_n > 1].describe())
df[['lemma_n']][df.lemma_n > 1].hist(bins=12)

# %% [markdown]
# ### Overlaps distributions

# %%
# compare the distributions of the overlap variables between annotations and web pages
print(df[['ann_overlap_token','ann_overlap_lemma','ann_overlap_tokenlemma']].describe().transpose())
df[['ann_overlap_token','ann_overlap_lemma','ann_overlap_tokenlemma','ann_overlap_criticwords','sem_similarity']].hist(bins=12)

df[['ann_overlap_tokenlemma']].hist(bins=12)
# Out:
#                            count      mean       std       min       25%  \
# ann_overlap_token       926924.0  0.195068  0.170000  0.000000  0.083330
# ann_overlap_lemma       926924.0  0.259498  0.148456  0.058820  0.166670
# ann_overlap_tokenlemma  926924.0  0.260216  0.149524  0.058824  0.166667
#
#                             50%       75%  max
# ann_overlap_token       0.16667  0.250000  1.0
# ann_overlap_lemma       0.25000  0.333330  1.0
# ann_overlap_tokenlemma  0.25000  0.333333  1.0
# array([[<AxesSubplot:title={'center':'ann_overlap_tokenlemma'}>]],
#       dtype=object)

# %%
# show length of annotations
print(df['example_len'].describe())
df['example_len'].hist(bins=10)

# filter annotations that are too short: valid df
df = df[df['example_len']>1]
print('matches with annotations > 1:', len(df))
# Out:
# count    926924.000000
# mean          5.926285
# std           2.919473
# min           2.000000
# 25%           4.000000
# 50%           5.000000
# 75%           7.000000
# max          17.000000
# Name: example_len, dtype: float64
# matches with annotations > 1: 926924

# %%
# count number of matches by indicator_code, to see which indicators are more or less popular
indic_df = df[['indicator_code','example_id']].groupby(['indicator_code']).describe()
indic_df = indic_df.sort_values(('example_id', 'unique'), ascending=False)
indic_df
# Out:
#                     example_id
#                          count unique           top   freq
# indicator_code
# funding_fundraise       128397     45  ann_ex_00111  12738
# lang_difficulty          72410     37  ann_ex_00160   5544
# reopen_intent           159688     35  ann_ex_00246  15645
# closed_cur              121016     21  ann_ex_00035  10644
# online_engag             28642     12  ann_ex_00177   5449
# funding_gov_emer         50763     11  ann_ex_00121   6490
# staff_working            49126     11  ann_ex_00275  21435
# open_onlineshop          51379      9  ann_ex_00205   7060
# staff_hiring             16865      8  ann_ex_00263   3958
# online_event             38586      8  ann_ex_00180   7302
# funding_did_not_get      27046      7  ann_ex_00056   8840
# online_exhib             36601      7  ann_ex_00190   8418
# finance_health            8005      6  ann_ex_00053   3975
# funding_other_emer        8167      4  ann_ex_00126   4598
# closed_indef             37087      4  ann_ex_00042  22205
# closed_perm              11632      4  ann_ex_00046   6590
# reopen_plan              14558      4  ann_ex_00256   6400
# open_cur                 42100      3  ann_ex_00198  26266
# project_postpone          6416      3  ann_ex_00210   3046
# made_covid_safe          11831      1  ann_ex_00167  11831
# open_cafe                 6605      1  ann_ex_00195   6605
# staff_restruct               4      1  ann_ex_00266      4

# %% [markdown]
# ## Evaluation of matching method
#
# This is to make sure that matching mechanism identifies matches in museum websites accurately. It uses supervised machine learning.
# This dataset is manually annotated by the team. It contains 700 entries of matches that are annotated as valid/not valid.
#
# Notes:
# - Manually annotated by AB, AP, PW.
# - Two independent annotators for each match.
# - Disagreement on 11.5% of cases, manually resolved in discussion with a third independent annotator.
# - in ann_ex_tokens, when the word "support" appears it implicitly intends to mean "financial support" whereas in the page_tokens "support" could be mean other types of support as well. Anyway, I marked these as "T" matches.
# - in ann_ex_tokens, phrases such as "currently closed" are implicitly intended to apply to the museum as a whole; whereas the page_tokens seem sometimes to be referreing to closures of parts of the museum, e.g. the grounds, the tea room etc.  I have generally marked these too as "T" matches.

# %% [markdown]
# ### Make sample of text matches
#
# Choose sample for manual annotation of matches stratified on overlap bins, to make sure that there is an even distribution. The bins are selected manually based on the distribution, observing high values more in detail than low values (which are almost certainly invalid matches).

# %%
# eval v2
if False:
    df['ann_overlap_tokenlemma']
    cut_bins = [0, .25, .5, .6, .7, .8, .9, 1.01]
    df['overlap_bin'] = pd.cut(df['ann_overlap_tokenlemma'], bins=cut_bins)
    df['overlap_bin'].value_counts()
    
# eval v3
if True:
    #print(df['ann_overlap_tokenlemma'].median())
    print(df['ann_overlap_tokenlemma'].quantile([0.,.25,.5,.75,.8,.9]))
    #pd.qcut(df['ann_overlap_tokenlemma'], 5)

    df['sem_similarity'].median()
    pd.qcut(df['sem_similarity'], 5)

    cut_bins = [0, .45, 1.01]
    df['overlap_bin'] = pd.cut(df['ann_overlap_tokenlemma'], bins=cut_bins)
    print(df['overlap_bin'].value_counts())
    
    n = 1000
    df.sample(n).to_excel(out_folder+'tmp/match_sample_for_validation_{}.xlsx'.format(n), index=False)
# Out:
# 0.00    0.058824
# 0.25    0.166667
# 0.50    0.250000
# 0.75    0.333333
# 0.80    0.333333
# 0.90    0.500000
# Name: ann_overlap_tokenlemma, dtype: float64
# (0.0, 0.45]     793121
# (0.45, 1.01]    133803
# Name: overlap_bin, dtype: int64

# %%
# Distribution of annotation lengths

# less than 0.2% of cases have annotation length == 1
#(len(df[df.example_len == 1])/len(df))*100

#df = df[df.example_len > 1]
df.example_len.describe()
# Out:
# count    889212.000000
# mean          5.942764
# std           2.928122
# min           2.000000
# 25%           4.000000
# 50%           5.000000
# 75%           7.000000
# max          17.000000
# Name: example_len, dtype: float64

# %%
# generate the stratified sample
sample_df = pd.DataFrame()
sample_n = 400
for bin_name, subdf in df.groupby('overlap_bin'):
    smpl = subdf.sample(sample_n, random_state=1359)
    sample_df = sample_df.append(smpl)
    
print(sample_df['overlap_bin'].value_counts())

sample_df['valid_match'] = ''

# shuffle sample
sample_df = sample_df.sample(frac=1.0)

# generate sample
sample_df.to_excel(out_folder+'tmp/match_sample_for_validation-v3.xlsx', index=False)

sample_df
# Out:
# (0.0, 0.45]     400
# (0.45, 1.01]    400
# Name: overlap_bin, dtype: int64
#                muse_id  page_id               sentence_id    example_id  \
# 258241  mm.domus.WA030   202439  mus_page202439_sent00008  ann_ex_00103
# 24058   mm.domus.SE116   406697  mus_page406697_sent00013  ann_ex_00026
# 72649      mm.wiki.150   507110  mus_page507110_sent00088  ann_ex_00227
# 95028      mm.ace.1089    53136   mus_page53136_sent00049  ann_ex_00167
# 614553  mm.domus.SC261   101660  mus_page101660_sent00008  ann_ex_00101
# ...                ...      ...                       ...           ...
# 880918  mm.domus.YH169   777180  mus_page777180_sent00820  ann_ex_00204
# 164614  mm.domus.YH043   853961  mus_page853961_sent00035  ann_ex_00042
# 730586  mm.domus.WM134   422309  mus_page422309_sent00072  ann_ex_00195
# 597829  mm.domus.SE530   329332  mus_page329332_sent00058  ann_ex_00042
# 988308  mm.domus.SE337   533210  mus_page533210_sent00056  ann_ex_00195
#
#            indicator_code session_id                       ann_ex_tokens  \
# 258241  funding_fundraise   20210304                       make donation
# 24058          closed_cur   20210304  currently closed government advice
# 72649       reopen_intent   20210304        we look forward seeing again
# 95028     made_covid_safe   20210304         find how we made visit safe
# 614553  funding_fundraise   20210304         every donation important us
# ...                   ...        ...                                 ...
# 880918    open_onlineshop   20210304        our online shop remains open
# 164614       closed_indef   20210304        museum closed further notice
# 730586          open_cafe   20210304                       our cafe open
# 597829       closed_indef   20210304        museum closed further notice
# 988308          open_cafe   20210304                       our cafe open
#
#                                               page_tokens  sem_similarity  \
# 258241  remembering education room hire support us mak...          0.7239
# 24058   we closed ancient house closed line government...          0.7584
# 72649   you can see up date availability book advance ...          0.8023
# 95028   managing ash dieback berrington find how we ta...          0.7761
# 614553  museum fully accredited member museums galleri...          0.7298
# ...                                                   ...             ...
# 880918                               online forms achieve          0.7182
# 164614  elisabeth fraser spencer stanhope last family ...          0.7192
# 730586  it so important everyone to fresh air birdsong...          0.7502
# 597829  read our full access statement pdf monk house ...          0.5644
# 988308  become patron coming soon our bronze silver go...          0.7744
#
#         token_n  ...  indicator_code_open_cur  indicator_code_open_onlineshop  \
# 258241      2.0  ...                        0                               0
# 24058       3.0  ...                        0                               0
# 72649       0.0  ...                        0                               0
# 95028       4.0  ...                        0                               0
# 614553      0.0  ...                        0                               0
# ...         ...  ...                      ...                             ...
# 880918      1.0  ...                        0                               1
# 164614      1.0  ...                        0                               0
# 730586      1.0  ...                        0                               0
# 597829      0.0  ...                        0                               0
# 988308      2.0  ...                        0                               0
#
#         indicator_code_project_postpone  indicator_code_reopen_intent  \
# 258241                                0                             0
# 24058                                 0                             0
# 72649                                 0                             1
# 95028                                 0                             0
# 614553                                0                             0
# ...                                 ...                           ...
# 880918                                0                             0
# 164614                                0                             0
# 730586                                0                             0
# 597829                                0                             0
# 988308                                0                             0
#
#         indicator_code_reopen_plan  indicator_code_staff_hiring  \
# 258241                           0                            0
# 24058                            0                            0
# 72649                            0                            0
# 95028                            0                            0
# 614553                           0                            0
# ...                            ...                          ...
# 880918                           0                            0
# 164614                           0                            0
# 730586                           0                            0
# 597829                           0                            0
# 988308                           0                            0
#
#         indicator_code_staff_restruct  indicator_code_staff_working  \
# 258241                              0                             0
# 24058                               0                             0
# 72649                               0                             0
# 95028                               0                             0
# 614553                              0                             0
# ...                               ...                           ...
# 880918                              0                             0
# 164614                              0                             0
# 730586                              0                             0
# 597829                              0                             0
# 988308                              0                             0
#
#          overlap_bin  valid_match
# 258241  (0.45, 1.01]
# 24058   (0.45, 1.01]
# 72649    (0.0, 0.45]
# 95028   (0.45, 1.01]
# 614553   (0.0, 0.45]
# ...              ...          ...
# 880918   (0.0, 0.45]
# 164614   (0.0, 0.45]
# 730586   (0.0, 0.45]
# 597829   (0.0, 0.45]
# 988308  (0.45, 1.01]
#
# [800 rows x 43 columns]

# %% [markdown]
# #### Eval data v1
#
# This version has no _critical word_ matches and is based on the match sample v5. Stored in _matches_valid_ann_df_v1.pik_.

# %%
valid_ann_df = pd.read_excel(out_folder+'data/annotations/match_sample_for_validation-v5.xlsx')
print(len(valid_ann_df))
print(valid_ann_df.columns)

# generate dummy vars
indicator_dummy_df = pd.get_dummies(valid_ann_df[['indicator_code']], drop_first=True)
indicator_dummy_vars = indicator_dummy_df.columns
print(valid_ann_df.shape)
valid_ann_df = pd.concat([valid_ann_df, indicator_dummy_df], axis=1)
print(valid_ann_df.shape)
print(indicator_dummy_vars)
valid_ann_df['valid_match_b'] = valid_ann_df['valid_match'].map({'T': True, 'F': False})
valid_ann_df['valid_match_b2'] = valid_ann_df['valid_match_2'].map({'T': True, 'F': False})
valid_ann_df.sample(10)

# add extra vars from matches
idx_cols = ['muse_id', 'example_id', 'sentence_id', 'indicator_code']
cols = idx_cols + ['txt_overlap_lemma','txt_overlap_token']
n = len(valid_ann_df)
valid_ann_df = valid_ann_df.merge(df[cols], on=idx_cols)
assert len(valid_ann_df) == n,len(valid_ann_df)

# derived fields
valid_ann_df["txt_overlap_tokenlemma"] = valid_ann_df[["txt_overlap_lemma", "txt_overlap_token"]].max(axis=1)

assert valid_ann_df.txt_overlap_tokenlemma.between(0,1).all(),'incorrect range'

valid_ann_df.to_pickle(out_folder+'tmp/matches_valid_ann_df_v1.pik')

# %% [markdown]
# #### Eval data v2
#
# This version includes the overlap with critical words (`ann_overlap_criticwords`). It is based on the match sample v5, joined with the full match information.

# %%
valid_ann_df = pd.read_excel(out_folder+'data/annotations/match_sample_for_validation-v5.xlsx')
orig_valid_ann_df = valid_ann_df
print(len(valid_ann_df))
print(valid_ann_df.columns)
print(len(df))

valid_matches = valid_ann_df[['muse_id','sentence_id','page_tokens','indicator_code',
                              'ann_ex_tokens','valid_match']].drop_duplicates()

all_matches = df

# Note: because IDs example_id mismatch, match rows based on tokens
assert len(all_matches)==881913,len(all_matches)
print(df.columns)

df2 = valid_matches.merge(all_matches, how='left',
            on=['muse_id','sentence_id','ann_ex_tokens','indicator_code','page_tokens']) 

#all_matches
valid_ann_df = df2.drop('example_id',axis=1).drop_duplicates()
valid_ann_df["txt_overlap_tokenlemma"] = valid_ann_df[["txt_overlap_lemma", "txt_overlap_token"]].max(axis=1)
n = 700

valid_ann_df = valid_ann_df.sample(n)
valid_ann_df = valid_ann_df[~valid_ann_df.lemma_n.isna()]

valid_ann_df['valid_match_b'] = valid_ann_df['valid_match'].map({'T': True, 'F': False})

# count invalid matches
#print(valid_ann_df[['ann_ex_tokens','valid_match_b']].value_counts().count())
#print(valid_ann_df[['ann_ex_tokens','valid_match_b']].pivot(index="ann_ex_tokens", columns="valid_match_b"))

indicator_dummy_df = pd.get_dummies(valid_ann_df[['indicator_code']], drop_first=True)
indicator_dummy_vars = indicator_dummy_df.columns
valid_ann_df = pd.concat([valid_ann_df, indicator_dummy_df], axis=1)

#del all_matches, valid_matches
print(len(valid_ann_df))
print(valid_ann_df.columns)
valid_ann_df.to_excel(out_folder+'tmp/match_sample_for_validation-v6.xlsx', index=False)

del df2
# Out:
#   File "/var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/329343396.py", line 1
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
# convert validation annotations to pikle
valid_ann_df = pd.read_excel(out_folder+'data/annotations/match_sample_for_validation-v6.xlsx')
print(len(valid_ann_df))
valid_ann_df.to_pickle(out_folder+'tmp/matches_valid_ann_df_v2.pik')
valid_ann_df.sample(5)

# %% [markdown]
# #### Eval data v3
#
# This version includes semantic similarity (19 Oct 2021).

# %%
valid_ann_df = pd.read_excel(out_folder+'data/annotations/match_sample_for_validation-v8.xlsx')
valid_ann_df['valid_match_b'] = valid_ann_df['valid_match'].map({'T': True, 'F': False})
valid_ann_df.to_pickle(out_folder+'tmp/matches_valid_ann_df_v3.pik')

indicator_dummy_df = pd.get_dummies(valid_ann_df[['indicator_code']], drop_first=True)
indicator_dummy_vars = indicator_dummy_df.columns

valid_ann_df['valid_match_b'].value_counts()
# Out:
# False    472
# True     228
# Name: valid_match_b, dtype: int64

# %%
valid_ann_df.describe()
# Out:
#             page_id  session_id  sem_similarity     token_n     lemma_n  \
# count  7.000000e+02       700.0      700.000000  700.000000  700.000000
# mean   4.334925e+05  20210304.0        0.716557    1.225714    1.531429
# std    2.841552e+05         0.0        0.117371    1.042952    0.920525
# min    2.600000e+01  20210304.0        0.205800    0.000000    1.000000
# 25%    1.829462e+05  20210304.0        0.640875    1.000000    1.000000
# 50%    4.263720e+05  20210304.0        0.725400    1.000000    1.000000
# 75%    6.604665e+05  20210304.0        0.802225    2.000000    2.000000
# max    1.069304e+06  20210304.0        0.991100    7.000000    7.000000
#
#        ann_overlap_lemma  ann_overlap_token  example_len  txt_overlap_lemma  \
# count         700.000000         700.000000   700.000000         700.000000
# mean            0.386781           0.298860     4.790000           0.167632
# std             0.211152           0.243723     2.713852           0.132202
# min             0.062500           0.000000     2.000000           0.017540
# 25%             0.200000           0.100000     2.000000           0.071430
# 50%             0.400000           0.250000     4.000000           0.125000
# 75%             0.500000           0.500000     6.000000           0.222220
# max             1.000000           1.000000    17.000000           1.000000
#
#        txt_overlap_token  ...  indicator_code_online_exhib  \
# count         700.000000  ...                   700.000000
# mean            0.133931  ...                     0.091429
# std             0.141762  ...                     0.288424
# min             0.000000  ...                     0.000000
# 25%             0.041252  ...                     0.000000
# 50%             0.100000  ...                     0.000000
# 75%             0.200000  ...                     0.000000
# max             1.000000  ...                     1.000000
#
#        indicator_code_open_cafe  indicator_code_open_cur  \
# count                700.000000               700.000000
# mean                   0.014286                 0.024286
# std                    0.118751                 0.154045
# min                    0.000000                 0.000000
# 25%                    0.000000                 0.000000
# 50%                    0.000000                 0.000000
# 75%                    0.000000                 0.000000
# max                    1.000000                 1.000000
#
#        indicator_code_open_onlineshop  indicator_code_project_postpone  \
# count                      700.000000                            700.0
# mean                         0.045714                              0.0
# std                          0.209014                              0.0
# min                          0.000000                              0.0
# 25%                          0.000000                              0.0
# 50%                          0.000000                              0.0
# 75%                          0.000000                              0.0
# max                          1.000000                              0.0
#
#        indicator_code_reopen_intent  indicator_code_reopen_plan  \
# count                    700.000000                  700.000000
# mean                       0.151429                    0.022857
# std                        0.358722                    0.149555
# min                        0.000000                    0.000000
# 25%                        0.000000                    0.000000
# 50%                        0.000000                    0.000000
# 75%                        0.000000                    0.000000
# max                        1.000000                    1.000000
#
#        indicator_code_staff_hiring  indicator_code_staff_restruct  \
# count                   700.000000                          700.0
# mean                      0.021429                            0.0
# std                       0.144912                            0.0
# min                       0.000000                            0.0
# 25%                       0.000000                            0.0
# 50%                       0.000000                            0.0
# 75%                       0.000000                            0.0
# max                       1.000000                            0.0
#
#        indicator_code_staff_working
# count                    700.000000
# mean                       0.065714
# std                        0.247959
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 35 columns]

# %%
# 20 found
valid_ann_df['indicator_code'].value_counts()
# Out:
# reopen_intent          106
# closed_cur              83
# funding_fundraise       74
# lang_difficulty         67
# online_exhib            64
# online_event            62
# staff_working           46
# open_onlineshop         32
# online_engag            28
# closed_indef            22
# funding_did_not_get     21
# funding_gov_emer        19
# open_cur                17
# reopen_plan             16
# staff_hiring            15
# open_cafe               10
# finance_health           7
# made_covid_safe          5
# closed_perm              4
# funding_other_emer       2
# Name: indicator_code, dtype: int64

# %% [markdown]
# ### Simple threshold method
#
# This is a matching method that uses only a threshold of `ann_overlap_tokenlemma` to select valid matches. It gives ok results, but not comparable to the other methods. Best result: accuracy .84, false positives 13%.

# %%
# observe distribution of value
len(valid_ann_df)
print(valid_ann_df.ann_overlap_tokenlemma.describe())
# Out:
# count    700.000000
# mean       0.388686
# std        0.212211
# min        0.062500
# 25%        0.200000
# 50%        0.400000
# 75%        0.500000
# max        1.000000
# Name: ann_overlap_tokenlemma, dtype: float64

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score

# test precision_recall_fscore_support function
precision_recall_fscore_support([True, False, True, False], [True, False, True, True], average='binary')
# Out:
# (0.6666666666666666, 1.0, 0.8, None)

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score

thdf = valid_ann_df.copy()

resdf = pd.DataFrame()

# loop through thresholds
for th in arange(.2,1.001,.05):
    print("---\nKeeping values ann_overlap_tokenlemma above: ",th)
    # PICK A VARIABLE
    thdf['predicted'] = thdf.ann_overlap_tokenlemma >= th
    #thdf['predicted'] = thdf.ann_overlap_criticwords >= th
    
    precision, recall, fscore, support = precision_recall_fscore_support(thdf.valid_match_b, thdf.predicted, average='binary')
    print(thdf.predicted.value_counts())
    stats = classification_report(thdf.valid_match_b, thdf.predicted)

    # confusion matrix
    confmat = confusion_matrix(thdf.valid_match_b, thdf.predicted, normalize='all')
    tn, fp, fn, tp = confmat.ravel()
    print('false positives %:',round(fp*100,1))

    subdf = pd.DataFrame.from_dict({'threshold':[th], 'precision':[round(precision,3)], 'recall':[round(recall,3)], 
            'fscore':[round(fscore,3)], 
            'accuracy': round(accuracy_score(thdf.valid_match_b, thdf.predicted),3),
            'false_positives': round(fp,3)})
    del tn, fp, fn, tp
    resdf = pd.concat([resdf, subdf])

resdf = resdf.reset_index()
resdf
# Out:
# ---
# Keeping values ann_overlap_tokenlemma above:  0.2
# True     550
# False    150
# Name: predicted, dtype: int64
# false positives %: 49.3
# ---
# Keeping values ann_overlap_tokenlemma above:  0.25
# True     492
# False    208
# Name: predicted, dtype: int64
# false positives %: 42.3
# ---
# Keeping values ann_overlap_tokenlemma above:  0.3
# True     410
# False    290
# Name: predicted, dtype: int64
# false positives %: 33.4
# ---
# Keeping values ann_overlap_tokenlemma above:  0.35
# True     361
# False    339
# Name: predicted, dtype: int64
# false positives %: 28.1
# ---
# Keeping values ann_overlap_tokenlemma above:  0.39999999999999997
# True     357
# False    343
# Name: predicted, dtype: int64
# false positives %: 27.7
# ---
# Keeping values ann_overlap_tokenlemma above:  0.44999999999999996
# False    353
# True     347
# Name: predicted, dtype: int64
# false positives %: 26.9
# ---
# Keeping values ann_overlap_tokenlemma above:  0.49999999999999994
# False    353
# True     347
# Name: predicted, dtype: int64
# false positives %: 26.9
# ---
# Keeping values ann_overlap_tokenlemma above:  0.5499999999999999
# False    616
# True      84
# Name: predicted, dtype: int64
# false positives %: 2.4
# ---
# Keeping values ann_overlap_tokenlemma above:  0.5999999999999999
# False    620
# True      80
# Name: predicted, dtype: int64
# false positives %: 2.1
# ---
# Keeping values ann_overlap_tokenlemma above:  0.6499999999999999
# False    632
# True      68
# Name: predicted, dtype: int64
# false positives %: 1.9
# ---
# Keeping values ann_overlap_tokenlemma above:  0.7
# False    649
# True      51
# Name: predicted, dtype: int64
# false positives %: 1.1
# ---
# Keeping values ann_overlap_tokenlemma above:  0.7499999999999998
# False    650
# True      50
# Name: predicted, dtype: int64
# false positives %: 1.1
# ---
# Keeping values ann_overlap_tokenlemma above:  0.7999999999999998
# False    665
# True      35
# Name: predicted, dtype: int64
# false positives %: 0.4
# ---
# Keeping values ann_overlap_tokenlemma above:  0.8499999999999999
# False    676
# True      24
# Name: predicted, dtype: int64
# false positives %: 0.3
# ---
# Keeping values ann_overlap_tokenlemma above:  0.8999999999999999
# False    676
# True      24
# Name: predicted, dtype: int64
# false positives %: 0.3
# ---
# Keeping values ann_overlap_tokenlemma above:  0.9499999999999997
# False    676
# True      24
# Name: predicted, dtype: int64
# false positives %: 0.3
# ---
# Keeping values ann_overlap_tokenlemma above:  0.9999999999999998
# False    676
# True      24
# Name: predicted, dtype: int64
# false positives %: 0.3
#     index  threshold  precision  recall  fscore  accuracy  false_positives
# 0       0       0.20      0.373   0.899   0.527     0.474            0.493
# 1       0       0.25      0.398   0.860   0.544     0.531            0.423
# 2       0       0.30      0.429   0.772   0.552     0.591            0.334
# 3       0       0.35      0.454   0.719   0.557     0.627            0.281
# 4       0       0.40      0.457   0.715   0.557     0.630            0.277
# 5       0       0.45      0.458   0.697   0.553     0.633            0.269
# 6       0       0.50      0.458   0.697   0.553     0.633            0.269
# 7       0       0.55      0.798   0.294   0.429     0.746            0.024
# 8       0       0.60      0.812   0.285   0.422     0.746            0.021
# 9       0       0.65      0.809   0.241   0.372     0.734            0.019
# 10      0       0.70      0.843   0.189   0.308     0.724            0.011
# 11      0       0.75      0.840   0.184   0.302     0.723            0.011
# 12      0       0.80      0.914   0.140   0.243     0.716            0.004
# 13      0       0.85      0.917   0.096   0.175     0.703            0.003
# 14      0       0.90      0.917   0.096   0.175     0.703            0.003
# 15      0       0.95      0.917   0.096   0.175     0.703            0.003
# 16      0       1.00      0.917   0.096   0.175     0.703            0.003

# %%
import seaborn as sns
p = sns.lineplot(data=resdf, x="threshold", y="accuracy", label='accuracy')
p = sns.lineplot(data=resdf, x="threshold", y="precision", label='precision')
p = sns.lineplot(data=resdf, x="threshold", y="recall", label='recall')
p = sns.lineplot(data=resdf, x="threshold", y="fscore", label='fscore')
p = sns.lineplot(data=resdf, x="threshold", y="false_positives", label='false_pos')
p.set(ylim=(0,1))
p.legend()

# %% [markdown]
# Show mean values by indicator code.

# %%
valid_ann_df.groupby('indicator_code').mean()
# Out:
#                            page_id  session_id  sem_similarity   token_n  \
# indicator_code
# closed_cur           373217.566265  20210304.0        0.695261  1.506024
# closed_indef         516619.590909  20210304.0        0.740173  1.681818
# closed_perm          476162.500000  20210304.0        0.735550  1.000000
# finance_health       369796.285714  20210304.0        0.812271  1.857143
# funding_did_not_get  432080.523810  20210304.0        0.722867  1.095238
# funding_fundraise    423608.162162  20210304.0        0.710309  1.081081
# funding_gov_emer     409432.736842  20210304.0        0.744368  1.157895
# funding_other_emer   738208.000000  20210304.0        0.725600  1.000000
# lang_difficulty      419961.865672  20210304.0        0.707358  0.746269
# made_covid_safe      489433.800000  20210304.0        0.781980  1.600000
# online_engag         452612.571429  20210304.0        0.704718  1.500000
# online_event         461367.725806  20210304.0        0.654845  0.822581
# online_exhib         422075.781250  20210304.0        0.634383  0.812500
# open_cafe            302953.900000  20210304.0        0.696720  0.700000
# open_cur             372296.588235  20210304.0        0.732829  1.411765
# open_onlineshop      416810.687500  20210304.0        0.756841  1.531250
# reopen_intent        451519.188679  20210304.0        0.778928  1.584906
# reopen_plan          467856.437500  20210304.0        0.731281  1.500000
# staff_hiring         407597.466667  20210304.0        0.720507  0.533333
# staff_working        519563.065217  20210304.0        0.753900  1.500000
#
#                       lemma_n  ann_overlap_lemma  ann_overlap_token  \
# indicator_code
# closed_cur           1.710843           0.346309           0.297701
# closed_indef         1.727273           0.467424           0.456060
# closed_perm          1.500000           0.252563           0.183333
# finance_health       2.142857           0.365079           0.307936
# funding_did_not_get  1.333333           0.252551           0.202949
# funding_fundraise    1.418919           0.343834           0.240786
# funding_gov_emer     1.526316           0.172819           0.117032
# funding_other_emer   1.000000           0.166670           0.166670
# lang_difficulty      1.179104           0.391902           0.245740
# made_covid_safe      1.800000           0.300002           0.266668
# online_engag         1.750000           0.448512           0.378968
# online_event         1.080645           0.497888           0.374616
# online_exhib         1.046875           0.492188           0.386719
# open_cafe            1.100000           0.366664           0.233331
# open_cur             1.823529           0.324866           0.231284
# open_onlineshop      1.656250           0.335677           0.307031
# reopen_intent        1.933962           0.388927           0.316341
# reopen_plan          1.875000           0.372323           0.280061
# staff_hiring         1.333333           0.366270           0.076191
# staff_working        1.869565           0.402096           0.332660
#
#                      example_len  txt_overlap_lemma  txt_overlap_token  ...  \
# indicator_code                                                          ...
# closed_cur              5.036145           0.189938           0.170921  ...
# closed_indef            3.818182           0.171290           0.171878  ...
# closed_perm             7.250000           0.110030           0.059525  ...
# finance_health          7.285714           0.162840           0.143113  ...
# funding_did_not_get     5.380952           0.099545           0.085748  ...
# funding_fundraise       5.662162           0.141059           0.106531  ...
# funding_gov_emer        9.894737           0.140411           0.120970  ...
# funding_other_emer      6.000000           0.048875           0.048875  ...
# lang_difficulty         4.447761           0.129723           0.082719  ...
# made_covid_safe         6.000000           0.130542           0.112360  ...
# online_engag            5.107143           0.205329           0.183661  ...
# online_event            2.338710           0.143028           0.110426  ...
# online_exhib            2.156250           0.151861           0.111709  ...
# open_cafe               3.000000           0.091802           0.040456  ...
# open_cur                6.470588           0.213474           0.154097  ...
# open_onlineshop         5.718750           0.219620           0.206860  ...
# reopen_intent           5.405660           0.204370           0.159353  ...
# reopen_plan             5.687500           0.206395           0.166031  ...
# staff_hiring            4.466667           0.133772           0.044445  ...
# staff_working           5.021739           0.189300           0.160065  ...
#
#                      indicator_code_open_cafe  indicator_code_open_cur  \
# indicator_code
# closed_cur                                0.0                      0.0
# closed_indef                              0.0                      0.0
# closed_perm                               0.0                      0.0
# finance_health                            0.0                      0.0
# funding_did_not_get                       0.0                      0.0
# funding_fundraise                         0.0                      0.0
# funding_gov_emer                          0.0                      0.0
# funding_other_emer                        0.0                      0.0
# lang_difficulty                           0.0                      0.0
# made_covid_safe                           0.0                      0.0
# online_engag                              0.0                      0.0
# online_event                              0.0                      0.0
# online_exhib                              0.0                      0.0
# open_cafe                                 1.0                      0.0
# open_cur                                  0.0                      1.0
# open_onlineshop                           0.0                      0.0
# reopen_intent                             0.0                      0.0
# reopen_plan                               0.0                      0.0
# staff_hiring                              0.0                      0.0
# staff_working                             0.0                      0.0
#
#                      indicator_code_open_onlineshop  \
# indicator_code
# closed_cur                                      0.0
# closed_indef                                    0.0
# closed_perm                                     0.0
# finance_health                                  0.0
# funding_did_not_get                             0.0
# funding_fundraise                               0.0
# funding_gov_emer                                0.0
# funding_other_emer                              0.0
# lang_difficulty                                 0.0
# made_covid_safe                                 0.0
# online_engag                                    0.0
# online_event                                    0.0
# online_exhib                                    0.0
# open_cafe                                       0.0
# open_cur                                        0.0
# open_onlineshop                                 1.0
# reopen_intent                                   0.0
# reopen_plan                                     0.0
# staff_hiring                                    0.0
# staff_working                                   0.0
#
#                      indicator_code_project_postpone  \
# indicator_code
# closed_cur                                       0.0
# closed_indef                                     0.0
# closed_perm                                      0.0
# finance_health                                   0.0
# funding_did_not_get                              0.0
# funding_fundraise                                0.0
# funding_gov_emer                                 0.0
# funding_other_emer                               0.0
# lang_difficulty                                  0.0
# made_covid_safe                                  0.0
# online_engag                                     0.0
# online_event                                     0.0
# online_exhib                                     0.0
# open_cafe                                        0.0
# open_cur                                         0.0
# open_onlineshop                                  0.0
# reopen_intent                                    0.0
# reopen_plan                                      0.0
# staff_hiring                                     0.0
# staff_working                                    0.0
#
#                      indicator_code_reopen_intent  indicator_code_reopen_plan  \
# indicator_code
# closed_cur                                    0.0                         0.0
# closed_indef                                  0.0                         0.0
# closed_perm                                   0.0                         0.0
# finance_health                                0.0                         0.0
# funding_did_not_get                           0.0                         0.0
# funding_fundraise                             0.0                         0.0
# funding_gov_emer                              0.0                         0.0
# funding_other_emer                            0.0                         0.0
# lang_difficulty                               0.0                         0.0
# made_covid_safe                               0.0                         0.0
# online_engag                                  0.0                         0.0
# online_event                                  0.0                         0.0
# online_exhib                                  0.0                         0.0
# open_cafe                                     0.0                         0.0
# open_cur                                      0.0                         0.0
# open_onlineshop                               0.0                         0.0
# reopen_intent                                 1.0                         0.0
# reopen_plan                                   0.0                         1.0
# staff_hiring                                  0.0                         0.0
# staff_working                                 0.0                         0.0
#
#                      indicator_code_staff_hiring  \
# indicator_code
# closed_cur                                   0.0
# closed_indef                                 0.0
# closed_perm                                  0.0
# finance_health                               0.0
# funding_did_not_get                          0.0
# funding_fundraise                            0.0
# funding_gov_emer                             0.0
# funding_other_emer                           0.0
# lang_difficulty                              0.0
# made_covid_safe                              0.0
# online_engag                                 0.0
# online_event                                 0.0
# online_exhib                                 0.0
# open_cafe                                    0.0
# open_cur                                     0.0
# open_onlineshop                              0.0
# reopen_intent                                0.0
# reopen_plan                                  0.0
# staff_hiring                                 1.0
# staff_working                                0.0
#
#                      indicator_code_staff_restruct  \
# indicator_code
# closed_cur                                     0.0
# closed_indef                                   0.0
# closed_perm                                    0.0
# finance_health                                 0.0
# funding_did_not_get                            0.0
# funding_fundraise                              0.0
# funding_gov_emer                               0.0
# funding_other_emer                             0.0
# lang_difficulty                                0.0
# made_covid_safe                                0.0
# online_engag                                   0.0
# online_event                                   0.0
# online_exhib                                   0.0
# open_cafe                                      0.0
# open_cur                                       0.0
# open_onlineshop                                0.0
# reopen_intent                                  0.0
# reopen_plan                                    0.0
# staff_hiring                                   0.0
# staff_working                                  0.0
#
#                      indicator_code_staff_working  valid_match_b
# indicator_code
# closed_cur                                    0.0       0.530120
# closed_indef                                  0.0       0.409091
# closed_perm                                   0.0       0.000000
# finance_health                                0.0       0.285714
# funding_did_not_get                           0.0       0.047619
# funding_fundraise                             0.0       0.378378
# funding_gov_emer                              0.0       0.105263
# funding_other_emer                            0.0       0.000000
# lang_difficulty                               0.0       0.119403
# made_covid_safe                               0.0       0.200000
# online_engag                                  0.0       0.642857
# online_event                                  0.0       0.145161
# online_exhib                                  0.0       0.187500
# open_cafe                                     0.0       0.000000
# open_cur                                      0.0       0.411765
# open_onlineshop                               0.0       0.250000
# reopen_intent                                 0.0       0.481132
# reopen_plan                                   0.0       0.562500
# staff_hiring                                  0.0       0.066667
# staff_working                                 1.0       0.391304
#
# [20 rows x 36 columns]

# %% [markdown]
# Show mean values by valid/not valid matches.

# %%
valid_ann_df.groupby('valid_match_b').mean()
# Out:
#                      page_id  session_id  sem_similarity   token_n   lemma_n  \
# valid_match_b
# False          421737.065678  20210304.0        0.683886  0.900424  1.241525
# True           457828.460526  20210304.0        0.784192  1.899123  2.131579
#
#                ann_overlap_lemma  ann_overlap_token  example_len  \
# valid_match_b
# False                   0.331773           0.229414     4.805085
# True                    0.500657           0.442625     4.758772
#
#                txt_overlap_lemma  txt_overlap_token  ...  \
# valid_match_b                                        ...
# False                   0.135450           0.096659  ...
# True                    0.234256           0.211090  ...
#
#                indicator_code_online_exhib  indicator_code_open_cafe  \
# valid_match_b
# False                             0.110169                  0.021186
# True                              0.052632                  0.000000
#
#                indicator_code_open_cur  indicator_code_open_onlineshop  \
# valid_match_b
# False                         0.021186                        0.050847
# True                          0.030702                        0.035088
#
#                indicator_code_project_postpone  indicator_code_reopen_intent  \
# valid_match_b
# False                                      0.0                      0.116525
# True                                       0.0                      0.223684
#
#                indicator_code_reopen_plan  indicator_code_staff_hiring  \
# valid_match_b
# False                            0.014831                     0.029661
# True                             0.039474                     0.004386
#
#                indicator_code_staff_restruct  indicator_code_staff_working
# valid_match_b
# False                                    0.0                      0.059322
# True                                     0.0                      0.078947
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Run traditional models
#
# Compare traditional classifiers, e.g. SVM, Logistic Regression, and generate the evaluation results in a data frame. Compare binary classifier to determine whether a match between an annotation and a sentence in a museum website is valid or not.
#
# - https://towardsdatascience.com/building-a-logistic-regression-in-python-step-by-step-becd4d56c9c8
# - https://www.analyticsvidhya.com/blog/2021/04/beginners-guide-to-logistic-regression-using-python/

# %%
# load ML packages
from sklearn import svm
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import plot_confusion_matrix, confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
def run_traditional_model(num_df, valid_ann_df_fn, var_group, test_size, clf):
    print('run_traditional_model', i, valid_ann_df_fn, len(var_group), test_size, clf)
    # prep data
    y_data = num_df['valid_match_b']
    x_data = num_df.drop('valid_match_b', axis = 1)
    x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x_data, y_data, test_size = test_size, random_state=2)

    # Train the model and create predictions
    clf.fit(x_training_data, y_training_data)
    predictions = clf.predict(x_test_data)

    # confusion matrix
    confmat = confusion_matrix(y_test_data, predictions, normalize='all')
    tn, fp, fn, tp = confmat.ravel()

    # evaluation metrics
    precision, recall, fscore, support = precision_recall_fscore_support(y_test_data, predictions, average='binary')
    acc = accuracy_score(y_test_data, predictions)
    del x_training_data, x_test_data, y_training_data, y_test_data

    # cross-validation
    crossval_predicted = cross_val_predict(clf, x_data, y_data, cv=6)
    crossval_acc = round(accuracy_score(y_data, crossval_predicted),2)
    del crossval_predicted

    # pack results
    subdf = pd.DataFrame.from_dict({
        'trial_i': i,
        'eval_file': valid_ann_df_fn,
        'var_group':' '.join(var_group),
        'model':str(clf), 'test_size':test_size, 'x_shape':str(x_data.shape),
        'accuracy': round(acc,2),
        'precision':[round(precision,3)], 'recall':[round(recall,3)], 
        'fscore':[round(fscore,3)], 
        'crossval_acc': crossval_acc,
        'false_pos': round(fp,2),'false_neg': round(fn,2)})
    return subdf

# prep variables
eval_dfs = [ 'matches_valid_ann_df_v3.pik']

in_var_groups = [
    #['txt_overlap_tokenlemma'],
    #['ann_overlap_tokenlemma'],
    #['ann_overlap_criticwords'],
    #['txt_overlap_token','txt_overlap_lemma','ann_overlap_criticwords'],
    #['txt_overlap_token','ann_overlap_criticwords','example_len'],
    ['lemmatoken_n','txt_overlap_token','ann_overlap_criticwords','example_len','sem_similarity'],
    ['lemmatoken_n','ann_overlap_tokenlemma','txt_overlap_lemma','example_len','sem_similarity'],
]

var_groups = []
for x in in_var_groups: 
    x1 = x.copy()
    x1.extend(indicator_dummy_vars.tolist()) 
    x.append('valid_match_b')
    x1.append('valid_match_b')
    var_groups.append(x)
    var_groups.append(x1)
    
# iterate over models
models = [
    #LogisticRegression(random_state=0),
    #svm.SVC(random_state=0),
    #MLPClassifier(random_state=1),
    #GaussianNB(),
    #KNeighborsClassifier(3),
    #SVC(kernel="linear", C=0.025),
    #SVC(gamma=2, C=1),
    #GaussianProcessClassifier(1.0 * RBF(1.0)),
    #DecisionTreeClassifier(max_depth=5)
]

for i in [5,10,20]:
    models.append(RandomForestClassifier(max_depth=i)) # random_state=10

split_sizes = [.3,.4,.5]
repeat_trials = 10

resdf = pd.DataFrame()
assert len(models) > 0

# generate all results (SLOW)
for valid_ann_df_fn in eval_dfs:
    # load validation dataset
    print(40*'-')
    print(valid_ann_df_fn)
    valid_ann_df = pd.read_pickle(out_folder+'data/annotations/'+valid_ann_df_fn)
    
    for var_group in var_groups:
        # extract numeric matrix
        #if not pd.Series(var_group).isin(valid_ann_df.columns).all():
        # skip
        #    continue
        print(valid_ann_df.columns)
        print(var_group)
        num_df = valid_ann_df[var_group]
        # loop through test sizes
        for test_size in split_sizes:
            # loop through models
            for clf in models:
                # repeat trial N times
                for i in range(repeat_trials):
                    subdf = run_traditional_model(num_df, valid_ann_df_fn, var_group, test_size, clf)
                    subdf['trial_i'] = i
                    resdf = pd.concat([resdf, subdf])
        del num_df
    del valid_ann_df

resdf = resdf.sort_values(by='accuracy', ascending=False)
resdf.to_excel(out_folder+'tmp/match_validation_comparison_traditional_models.xlsx', index=False)
resdf
# Out:
# ----------------------------------------
# matches_valid_ann_df_v3.pik
# Index(['muse_id', 'page_id', 'sentence_id', 'example_id', 'indicator_code',
#        'session_id', 'ann_ex_tokens', 'page_tokens', 'sem_similarity',
#        'token_n', 'lemma_n', 'ann_overlap_lemma', 'ann_overlap_token',
#        'example_len', 'txt_overlap_lemma', 'txt_overlap_token',
#        'ann_overlap_criticwords', 'lemmatoken_n', 'ann_overlap_tokenlemma',
#        'txt_overlap_tokenlemma', 'indicator_code_closed_indef',
#        'indicator_code_closed_perm', 'indicator_code_finance_health',
#        'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working', 'overlap_bin', 'valid_match',
#        'valid_match_b'],
#       dtype='object')
# ['lemmatoken_n', 'txt_overlap_token', 'ann_overlap_criticwords', 'example_len', 'sem_similarity', 'valid_match_b']
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# Index(['muse_id', 'page_id', 'sentence_id', 'example_id', 'indicator_code',
#        'session_id', 'ann_ex_tokens', 'page_tokens', 'sem_similarity',
#        'token_n', 'lemma_n', 'ann_overlap_lemma', 'ann_overlap_token',
#        'example_len', 'txt_overlap_lemma', 'txt_overlap_token',
#        'ann_overlap_criticwords', 'lemmatoken_n', 'ann_overlap_tokenlemma',
#        'txt_overlap_tokenlemma', 'indicator_code_closed_indef',
#        'indicator_code_closed_perm', 'indicator_code_finance_health',
#        'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working', 'overlap_bin', 'valid_match',
#        'valid_match_b'],
#       dtype='object')
# ['lemmatoken_n', 'txt_overlap_token', 'ann_overlap_criticwords', 'example_len', 'sem_similarity', 'indicator_code_closed_indef', 'indicator_code_closed_perm', 'indicator_code_finance_health', 'indicator_code_funding_did_not_get', 'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer', 'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty', 'indicator_code_made_covid_safe', 'indicator_code_online_engag', 'indicator_code_online_event', 'indicator_code_online_exhib', 'indicator_code_open_cafe', 'indicator_code_open_cur', 'indicator_code_open_onlineshop', 'indicator_code_reopen_intent', 'indicator_code_reopen_plan', 'indicator_code_staff_hiring', 'indicator_code_staff_working', 'valid_match_b']
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# Index(['muse_id', 'page_id', 'sentence_id', 'example_id', 'indicator_code',
#        'session_id', 'ann_ex_tokens', 'page_tokens', 'sem_similarity',
#        'token_n', 'lemma_n', 'ann_overlap_lemma', 'ann_overlap_token',
#        'example_len', 'txt_overlap_lemma', 'txt_overlap_token',
#        'ann_overlap_criticwords', 'lemmatoken_n', 'ann_overlap_tokenlemma',
#        'txt_overlap_tokenlemma', 'indicator_code_closed_indef',
#        'indicator_code_closed_perm', 'indicator_code_finance_health',
#        'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working', 'overlap_bin', 'valid_match',
#        'valid_match_b'],
#       dtype='object')
# ['lemmatoken_n', 'ann_overlap_tokenlemma', 'txt_overlap_lemma', 'example_len', 'sem_similarity', 'valid_match_b']
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 6 0.5 RandomForestClassifier(max_depth=20)
# Index(['muse_id', 'page_id', 'sentence_id', 'example_id', 'indicator_code',
#        'session_id', 'ann_ex_tokens', 'page_tokens', 'sem_similarity',
#        'token_n', 'lemma_n', 'ann_overlap_lemma', 'ann_overlap_token',
#        'example_len', 'txt_overlap_lemma', 'txt_overlap_token',
#        'ann_overlap_criticwords', 'lemmatoken_n', 'ann_overlap_tokenlemma',
#        'txt_overlap_tokenlemma', 'indicator_code_closed_indef',
#        'indicator_code_closed_perm', 'indicator_code_finance_health',
#        'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working', 'overlap_bin', 'valid_match',
#        'valid_match_b'],
#       dtype='object')
# ['lemmatoken_n', 'ann_overlap_tokenlemma', 'txt_overlap_lemma', 'example_len', 'sem_similarity', 'indicator_code_closed_indef', 'indicator_code_closed_perm', 'indicator_code_finance_health', 'indicator_code_funding_did_not_get', 'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer', 'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty', 'indicator_code_made_covid_safe', 'indicator_code_online_engag', 'indicator_code_online_event', 'indicator_code_online_exhib', 'indicator_code_open_cafe', 'indicator_code_open_cur', 'indicator_code_open_onlineshop', 'indicator_code_reopen_intent', 'indicator_code_reopen_plan', 'indicator_code_staff_hiring', 'indicator_code_staff_working', 'valid_match_b']
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.3 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.4 RandomForestClassifier(max_depth=20)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=5)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=10)
# run_traditional_model 0 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 1 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 2 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 3 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 4 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 5 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 6 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 7 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 8 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
# run_traditional_model 9 matches_valid_ann_df_v3.pik 25 0.5 RandomForestClassifier(max_depth=20)
#     trial_i                    eval_file  \
# 0         8  matches_valid_ann_df_v3.pik
# 0         2  matches_valid_ann_df_v3.pik
# 0         9  matches_valid_ann_df_v3.pik
# 0         4  matches_valid_ann_df_v3.pik
# 0         5  matches_valid_ann_df_v3.pik
# ..      ...                          ...
# 0         5  matches_valid_ann_df_v3.pik
# 0         3  matches_valid_ann_df_v3.pik
# 0         3  matches_valid_ann_df_v3.pik
# 0         4  matches_valid_ann_df_v3.pik
# 0         5  matches_valid_ann_df_v3.pik
#
#                                             var_group  \
# 0   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 0   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 0   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 0   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 0   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# ..                                                ...
# 0   lemmatoken_n txt_overlap_token ann_overlap_cri...
# 0   lemmatoken_n txt_overlap_token ann_overlap_cri...
# 0   lemmatoken_n txt_overlap_token ann_overlap_cri...
# 0   lemmatoken_n txt_overlap_token ann_overlap_cri...
# 0   lemmatoken_n txt_overlap_token ann_overlap_cri...
#
#                                    model  test_size    x_shape  accuracy  \
# 0    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.81
# 0    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# 0   RandomForestClassifier(max_depth=20)        0.3  (700, 24)      0.80
# 0    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# 0    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# ..                                   ...        ...        ...       ...
# 0   RandomForestClassifier(max_depth=10)        0.4   (700, 5)      0.72
# 0   RandomForestClassifier(max_depth=10)        0.4   (700, 5)      0.72
# 0   RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.72
# 0   RandomForestClassifier(max_depth=10)        0.5   (700, 5)      0.72
# 0   RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.71
#
#     precision  recall  fscore  crossval_acc  false_pos  false_neg
# 0       0.753   0.577   0.653          0.79       0.06       0.13
# 0       0.717   0.595   0.650          0.79       0.07       0.13
# 0       0.721   0.629   0.672          0.77       0.08       0.12
# 0       0.722   0.586   0.647          0.79       0.07       0.13
# 0       0.722   0.586   0.647          0.79       0.07       0.13
# ..        ...     ...     ...           ...        ...        ...
# 0       0.615   0.495   0.549          0.77       0.11       0.18
# 0       0.635   0.485   0.550          0.77       0.10       0.18
# 0       0.618   0.485   0.543          0.77       0.10       0.18
# 0       0.569   0.523   0.545          0.77       0.13       0.15
# 0       0.608   0.464   0.526          0.76       0.10       0.19
#
# [360 rows x 13 columns]

# %% [markdown]
# ### Feature selection (OLD)
#
# Quantify contribution of each variable in the matching process using recursive feature elimination (RFE).

# %%
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

def backward_elimination():
    """ TODO """
    cols = list(X.columns)
    pmax = 1
    while (len(cols)>0):
        p= []
        X_1 = X[cols]
        X_1 = sm.add_constant(X_1)
        model = sm.OLS(y,X_1).fit()
        p = pd.Series(model.pvalues.values[1:],index = cols)      
        pmax = max(p)
        feature_with_p_max = p.idxmax()
        if(pmax>0.05):
            cols.remove(feature_with_p_max)
        else:
            break
    selected_features_BE = cols
    print(selected_features_BE)
    return selected_features_BE

eval_dfs = ['matches_valid_ann_df_v3.pik']

for valid_ann_df_fn in eval_dfs:
    # load validation dataset
    print(40*'-')
    print(valid_ann_df_fn)
    valid_ann_df = pd.read_pickle(out_folder+'data/annotations/'+valid_ann_df_fn)
    x_data = valid_ann_df.select_dtypes(include=[np.number])
    x_data = x_data.drop(['ann_overlap_tokenlemma','txt_overlap_tokenlemma'], axis = 1)
    print(len(valid_ann_df))
    y_data = valid_ann_df['valid_match_b']

    if False:
        # create pipeline with stratified K fold
        model = RandomForestClassifier(max_depth=5, random_state=10)
        model_est = RandomForestClassifier(max_depth=5, random_state=10)
        rfe = RFE(estimator=model_est, n_features_to_select=5)
        pipeline = Pipeline(steps=[('s',rfe),('m',model)])
        # evaluate model
        cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=10)
        n_scores = cross_val_score(pipeline, x_data, y_data, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
        # report performance
        print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))
    if True:
        estimator = RandomForestClassifier(max_depth=5, random_state=10)
        # Recursive Feature Elimination (RFE)
        selector = RFE(estimator, n_features_to_select=5, step=1)
        selector = selector.fit(x_data, y_data)
        print(selector.support_)
        print(selector.ranking_)
        from operator import itemgetter
        features = x_data.columns.to_list()
        for x, y in (sorted(zip(selector.ranking_ , features), key=itemgetter(0))):
            print(x, y)

# %% [markdown]
# ### Deep Learning
#
# Find valid matches using deep learning and `keras`.
#
# - https://machinelearningmastery.com/tutorial-first-neural-network-python-keras
# - https://machinelearningmastery.com/custom-metrics-deep-learning-keras-python/

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.metrics import FalsePositives, BinaryAccuracy
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot
from numpy import mean
from numpy import std

# https://stackoverflow.com/questions/48285129/saving-best-model-in-keras/48286003
early_stopping_monitor = EarlyStopping(
    monitor='binary_accuracy',
    min_delta=0,
    patience=150,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

def build_convolutional_nn(input_dim, neurons):
    print('build_convolutional_nn: ', input_dim, neurons)
    model = Sequential()
    # add first layer
    model.add(Dense(neurons[0], input_dim=input_dim, activation='relu'))
    # add intermediate layers
    for neur in neurons[1:]:
        model.add(Dense(neur, activation='relu'))
    # add final layer
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[BinaryAccuracy()])
    return model


def run_deep_learning(df, test_size, neurons, batch_size, early_stopping_monitor=early_stopping_monitor):
    """ create and call a Keras model with layers """
    print('run_deep_learning', df.shape, test_size, neurons, batch_size)
    # get only numeric columns
    x_data = df.select_dtypes(include=[np.number])
    x_data = x_data.drop(columns=['page_id', 'session_id'])
    
    if True:
        # create scaler
        scaler = MinMaxScaler()
        # fit and transform in one step
        cols = x_data.columns
        x_data = pd.DataFrame(scaler.fit_transform(x_data),columns=cols)
    
    y_data = df[['valid_match_b']]
    # train/test split
    x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x_data, y_data, test_size = test_size)
    #print('train/test',x_training_data.shape, x_test_data.shape, y_training_data.shape, y_test_data.shape)

    # define the keras model
    model = build_convolutional_nn(len(x_data.columns), neurons)
    
    if True:
        # fit model
        # https://keras.io/guides/training_with_built_in_methods/
        history = model.fit(x_training_data, y_training_data, epochs=150, batch_size=batch_size, verbose=0,
                           callbacks=[early_stopping_monitor]) # , validation_split=test_size
        # plot metrics
        #pyplot.plot(history.history['binary_accuracy'])
        #pyplot.show()
        # evaluate model
        loss, accuracy = model.evaluate(x_test_data, y_test_data, verbose=0)
        print("-> acc ",accuracy)
        # get predicted values
        pred_y = (model.predict(x_test_data) > 0.5).astype("bool")
        # unpack results
        pred_y = [item for sublist in pred_y for item in sublist]
        # calculate IR metrics
        precision, recall, fscore, support = precision_recall_fscore_support(y_test_data, pred_y, average='binary')        
        # calculate confusion matrix
        confmat = confusion_matrix(y_test_data, pred_y, normalize='all')
        tn, fp, fn, tp = confmat.ravel()
        del pred_y
        # save results
        res_d = {
            'neurons': [str(neurons)],
            'batch_size': [batch_size],
            'test_size_split': [test_size],
            'x_shape': [str(x_data.shape)],
            'accuracy': [round(accuracy,3)],
            'precision': [round(precision,3)],
            'recall': [round(recall,3)],
            'fscore': [round(fscore,3)],
            'true_pos': [round(tp,3)],
            'true_neg': [round(tn,3)],
            'false_pos': [round(fp,3)],
            'false_neg': [round(fn,3)],
            'loss': [round(loss,3)],
            'accuracy_train_max': [round(max(history.history['binary_accuracy']),3)]
        }
        del tn, fp, fn, tp
        return res_d, model, x_data.columns

    if False:
        # cross validation
        #estimator = KerasClassifier(build_fn=model, epochs=100, batch_size=5, verbose=0)
        #kfold = StratifiedKFold(n_splits=10, shuffle=True)
        #results = cross_val_score(estimator, x_data, y_data, cv=kfold)
        #print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
        estimators = []
        estimators.append(('standardize', StandardScaler()))
        estimators.append(('mlp', KerasClassifier(build_fn=model, epochs=100, batch_size=5, verbose=0)))
        pipeline = Pipeline(estimators)
        kfold = StratifiedKFold(n_splits=10, shuffle=True)
        results = cross_val_score(pipeline, x_data, y_data, cv=kfold)
        print("Smaller: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %%
# set input for deep learning        
valid_ann_df_fn = 'matches_valid_ann_df_v3.pik'
valid_ann_df = pd.read_pickle(out_folder+'data/annotations/'+valid_ann_df_fn)

neuron_blocks = [
    [8],
    [8,16],
    [32,32],
    [8,16,32],
    [256,512],
    [32,64,512]
]
n_trials = 10
test_split_sizes = [.3,.4,.5] # [.4]
batch_sizes = [1,8,32] #[1,8,32]

# loop over parameters
resdf = pd.DataFrame()

for batch_size in batch_sizes:
    for test_size in test_split_sizes:
        for neur in neuron_blocks:
            print("-"*40)
            for i in range(n_trials):
                res_d, _ = run_deep_learning(valid_ann_df, test_size, neur, batch_size)
                df = pd.DataFrame.from_dict(res_d)
                df['trial'] = i
                resdf = pd.concat([resdf, df])
                del df
            
resdf = resdf.reset_index()
resdf.to_excel(out_folder+'tmp/match_validation_model_comparison_deeplearning.xlsx', index=False)

del valid_ann_df, test_split_sizes, neuron_blocks, n_trials, valid_ann_df_fn

resdf
# Out:
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8190476298332214
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8095238208770752
# run_deep_learning (700, 44) 0.3 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7857142686843872
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8095238208770752
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7523809671401978
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7095237970352173
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8238095045089722
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.723809540271759
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8333333134651184
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7333333492279053
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7904762029647827
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7190476059913635
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7190476059913635
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.723809540271759
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.738095223903656
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7428571581840515
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.723809540271759
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.8095238208770752
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7142857313156128
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7047619223594666
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.8095238208770752
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7607142925262451
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8107143044471741
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7607142925262451
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8071428537368774
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7321428656578064
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7892857193946838
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7214285731315613
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7357142567634583
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7642857432365417
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7214285731315613
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7392857074737549
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7392857074737549
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.6892856955528259
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7749999761581421
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7178571224212646
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.6928571462631226
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.6964285969734192
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7535714507102966
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8199999928474426
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.831428587436676
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7828571200370789
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8] 1
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7599999904632568
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7457143068313599
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8, 16] 1
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7371428608894348
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7628571391105652
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7828571200370789
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7314285635948181
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7599999904632568
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7371428608894348
# run_deep_learning (700, 44) 0.5 [32, 32] 1
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7514285445213318
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7485714554786682
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7457143068313599
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7457143068313599
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7342857122421265
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7485714554786682
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 1
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7599999904632568
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7114285826683044
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7400000095367432
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.8057143092155457
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7599999904632568
# run_deep_learning (700, 44) 0.5 [256, 512] 1
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7342857122421265
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7771428823471069
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7342857122421265
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7400000095367432
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7514285445213318
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 1
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7514285445213318
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8285714387893677
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8285714387893677
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8095238208770752
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.738095223903656
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8380952477455139
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.738095223903656
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7809523940086365
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7904762029647827
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8047618865966797
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7904762029647827
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7190476059913635
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7333333492279053
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7333333492279053
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.738095223903656
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7333333492279053
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7142857313156128
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7928571701049805
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7928571701049805
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7892857193946838
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7357142567634583
# run_deep_learning (700, 44) 0.4 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7607142925262451
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8178571462631226
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.75
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7250000238418579
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7178571224212646
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7214285731315613
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7392857074737549
# run_deep_learning (700, 44) 0.4 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.8107143044471741
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.6857143044471741
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7964285612106323
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7321428656578064
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7321428656578064
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7928571701049805
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7464285492897034
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7392857074737549
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7828571200370789
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.8199999928474426
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [8] 8
# build_convolutional_nn:  35 [8]
# -> acc  0.7742857336997986
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7599999904632568
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.808571457862854
# run_deep_learning (700, 44) 0.5 [8, 16] 8
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7799999713897705
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7514285445213318
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7628571391105652
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [32, 32] 8
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7314285635948181
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7599999904632568
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7685714364051819
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7628571391105652
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 8
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7285714149475098
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7542856931686401
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7342857122421265
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7200000286102295
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7285714149475098
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7400000095367432
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [256, 512] 8
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7228571176528931
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7457143068313599
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7028571367263794
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7514285445213318
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7542856931686401
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7342857122421265
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 8
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7400000095367432
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7904762029647827
# run_deep_learning (700, 44) 0.3 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8380952477455139
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8428571224212646
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8190476298332214
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8333333134651184
# run_deep_learning (700, 44) 0.3 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7714285850524902
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8047618865966797
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7904762029647827
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8285714387893677
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.3 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7809523940086365
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8238095045089722
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7904762029647827
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.776190459728241
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8095238208770752
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7952380776405334
# run_deep_learning (700, 44) 0.3 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7333333492279053
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7666666507720947
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7714285850524902
# ----------------------------------------
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7523809671401978
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7809523940086365
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7476190328598022
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.761904776096344
# run_deep_learning (700, 44) 0.3 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.738095223903656
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7928571701049805
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8035714030265808
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8071428537368774
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8321428298950195
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8214285969734192
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8071428537368774
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7928571701049805
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8071428537368774
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.800000011920929
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7642857432365417
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8107143044471741
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7928571701049805
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.8035714030265808
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7821428775787354
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7892857193946838
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8321428298950195
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7964285612106323
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7749999761581421
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7678571343421936
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7357142567634583
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7535714507102966
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7607142925262451
# run_deep_learning (700, 44) 0.4 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7678571343421936
# ----------------------------------------
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7142857313156128
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.75
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7785714268684387
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.4 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7464285492897034
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8142856955528259
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7314285635948181
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.800000011920929
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7628571391105652
# run_deep_learning (700, 44) 0.5 [8] 32
# build_convolutional_nn:  35 [8]
# -> acc  0.7714285850524902
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7828571200370789
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8028571605682373
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7828571200370789
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8285714387893677
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.808571457862854
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.8057143092155457
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [8, 16] 32
# build_convolutional_nn:  35 [8, 16]
# -> acc  0.7857142686843872
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7771428823471069
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.808571457862854
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [32, 32] 32
# build_convolutional_nn:  35 [32, 32]
# -> acc  0.7971428632736206
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7885714173316956
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7942857146263123
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8114285469055176
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8199999928474426
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.8114285469055176
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7799999713897705
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7857142686843872
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [8, 16, 32] 32
# build_convolutional_nn:  35 [8, 16, 32]
# -> acc  0.7714285850524902
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7342857122421265
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7200000286102295
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7714285850524902
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7171428799629211
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7914285659790039
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7485714554786682
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7571428418159485
# run_deep_learning (700, 44) 0.5 [256, 512] 32
# build_convolutional_nn:  35 [256, 512]
# -> acc  0.7914285659790039
# ----------------------------------------
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7428571581840515
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7171428799629211
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7742857336997986
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.6971428394317627
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7657142877578735
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.677142858505249
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7457143068313599
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7085714340209961
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7485714554786682
# run_deep_learning (700, 44) 0.5 [32, 64, 512] 32
# build_convolutional_nn:  35 [32, 64, 512]
# -> acc  0.7371428608894348
#      index        neurons  batch_size  test_size_split    x_shape  accuracy  \
# 0        0            [8]           1              0.3  (700, 35)     0.800
# 1        0            [8]           1              0.3  (700, 35)     0.748
# 2        0            [8]           1              0.3  (700, 35)     0.752
# 3        0            [8]           1              0.3  (700, 35)     0.800
# 4        0            [8]           1              0.3  (700, 35)     0.776
# ..     ...            ...         ...              ...        ...       ...
# 535      0  [32, 64, 512]          32              0.5  (700, 35)     0.677
# 536      0  [32, 64, 512]          32              0.5  (700, 35)     0.746
# 537      0  [32, 64, 512]          32              0.5  (700, 35)     0.709
# 538      0  [32, 64, 512]          32              0.5  (700, 35)     0.749
# 539      0  [32, 64, 512]          32              0.5  (700, 35)     0.737
#
#      precision  recall  fscore  true_pos  true_neg  false_pos  false_neg  \
# 0        0.700   0.636   0.667     0.200     0.600      0.086      0.114
# 1        0.672   0.573   0.619     0.205     0.543      0.100      0.152
# 2        0.633   0.559   0.594     0.181     0.571      0.105      0.143
# 3        0.690   0.710   0.700     0.233     0.567      0.105      0.095
# 4        0.634   0.448   0.525     0.124     0.652      0.071      0.152
# ..         ...     ...     ...       ...       ...        ...        ...
# 535      0.492   0.791   0.606     0.249     0.429      0.257      0.066
# 536      0.588   0.688   0.634     0.220     0.526      0.154      0.100
# 537      0.504   0.592   0.545     0.174     0.534      0.171      0.120
# 538      0.610   0.632   0.621     0.206     0.543      0.131      0.120
# 539      0.620   0.534   0.574     0.177     0.560      0.109      0.154
#
#       loss  accuracy_train_max  trial
# 0    0.622               0.886      0
# 1    0.670               0.882      1
# 2    0.563               0.890      2
# 3    0.731               0.857      3
# 4    0.593               0.861      4
# ..     ...                 ...    ...
# 535  1.702               0.983      5
# 536  1.642               0.986      6
# 537  1.915               0.989      7
# 538  2.448               1.000      8
# 539  1.998               0.986      9
#
# [540 rows x 16 columns]

# %% [markdown]
# ### Summarise trials
#
# - The best of traditional models overall is RandomForestClassifier(max_depth=XXXXX), similar to depth XXXXX. Average accuracy XXXXX.

# %%
# summary of trials
fn = out_folder+'data/analysis/matching_validation/match_validation_comparison_traditional_models-v3.xlsx'
resdf = pd.read_excel(fn)
resdf = resdf.sort_values(['accuracy'], ascending=False)
resdf
# Out:
#      trial_i                    eval_file  \
# 30         8  matches_valid_ann_df_v3.pik
# 31         7  matches_valid_ann_df_v3.pik
# 32         2  matches_valid_ann_df_v3.pik
# 33         4  matches_valid_ann_df_v3.pik
# 34         5  matches_valid_ann_df_v3.pik
# ..       ...                          ...
# 352        6  matches_valid_ann_df_v3.pik
# 353        3  matches_valid_ann_df_v3.pik
# 137        6  matches_valid_ann_df_v3.pik
# 341        4  matches_valid_ann_df_v3.pik
# 358        5  matches_valid_ann_df_v3.pik
#
#                                              var_group  \
# 30   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 31   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 32   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 33   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 34   lemmatoken_n ann_overlap_tokenlemma txt_overla...
# ..                                                 ...
# 352  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 353  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 137  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 341  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 358  lemmatoken_n txt_overlap_token ann_overlap_cri...
#
#                                     model  test_size    x_shape  accuracy  \
# 30    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.81
# 31    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# 32    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# 33    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# 34    RandomForestClassifier(max_depth=5)        0.5  (700, 24)      0.80
# ..                                    ...        ...        ...       ...
# 352  RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.72
# 353  RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.72
# 137  RandomForestClassifier(max_depth=20)        0.5   (700, 5)      0.72
# 341  RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.72
# 358  RandomForestClassifier(max_depth=20)        0.4   (700, 5)      0.71
#
#      precision  recall  fscore  crossval_acc  false_pos  false_neg
# 30       0.753   0.577   0.653          0.79       0.06       0.13
# 31       0.725   0.595   0.653          0.79       0.07       0.13
# 32       0.717   0.595   0.650          0.79       0.07       0.13
# 33       0.722   0.586   0.647          0.79       0.07       0.13
# 34       0.722   0.586   0.647          0.79       0.07       0.13
# ..         ...     ...     ...           ...        ...        ...
# 352      0.639   0.474   0.544          0.76       0.09       0.18
# 353      0.618   0.485   0.543          0.77       0.10       0.18
# 137      0.560   0.550   0.555          0.77       0.14       0.14
# 341      0.632   0.495   0.555          0.77       0.10       0.18
# 358      0.608   0.464   0.526          0.76       0.10       0.19
#
# [360 rows x 13 columns]

# %%
desc_df = resdf[['model','accuracy','precision','recall','fscore','false_pos']].groupby(['model']).mean().round(2)
#desc_df = desc_df.sort_values(('accuracy'), ascending=False)
desc_df
# Out:
#                                       accuracy  precision  recall  fscore  \
# model
# RandomForestClassifier(max_depth=10)      0.76       0.68    0.54    0.60
# RandomForestClassifier(max_depth=20)      0.76       0.67    0.57    0.61
# RandomForestClassifier(max_depth=5)       0.77       0.71    0.52    0.60
#
#                                       false_pos
# model
# RandomForestClassifier(max_depth=10)       0.09
# RandomForestClassifier(max_depth=20)       0.10
# RandomForestClassifier(max_depth=5)        0.07

# %% [markdown]
# Summarise best random forest trials to check for model stability.

# %%
fn = out_folder+'data/analysis/matching_validation/match_validation_comparison_traditional_models_top_randomforests-v1.xlsx'
resdf = pd.read_excel(fn)
print(resdf.columns)
resdf
# Out:
# Index(['trial_i', 'eval_file', 'var_group', 'model', 'test_size', 'x_shape',
#        'accuracy', 'precision', 'recall', 'fscore', 'crossval_acc',
#        'false_pos', 'false_neg'],
#       dtype='object')
#      trial_i                    eval_file  \
# 0          0  matches_valid_ann_df_v2.pik
# 1          1  matches_valid_ann_df_v2.pik
# 2          2  matches_valid_ann_df_v2.pik
# 3          3  matches_valid_ann_df_v2.pik
# 4          4  matches_valid_ann_df_v2.pik
# ..       ...                          ...
# 355        5  matches_valid_ann_df_v2.pik
# 356        6  matches_valid_ann_df_v2.pik
# 357        7  matches_valid_ann_df_v2.pik
# 358        8  matches_valid_ann_df_v2.pik
# 359        9  matches_valid_ann_df_v2.pik
#
#                                              var_group  \
# 0    lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 1    lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 2    lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 3    lemmatoken_n ann_overlap_tokenlemma txt_overla...
# 4    lemmatoken_n ann_overlap_tokenlemma txt_overla...
# ..                                                 ...
# 355  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 356  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 357  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 358  lemmatoken_n txt_overlap_token ann_overlap_cri...
# 359  lemmatoken_n txt_overlap_token ann_overlap_cri...
#
#                                     model  test_size    x_shape  accuracy  \
# 0    RandomForestClassifier(max_depth=10)        0.3  (700, 23)      0.87
# 1    RandomForestClassifier(max_depth=10)        0.3  (700, 23)      0.87
# 2    RandomForestClassifier(max_depth=10)        0.3  (700, 23)      0.86
# 3    RandomForestClassifier(max_depth=10)        0.3  (700, 23)      0.87
# 4    RandomForestClassifier(max_depth=10)        0.3  (700, 23)      0.87
# ..                                    ...        ...        ...       ...
# 355   RandomForestClassifier(max_depth=5)        0.5   (700, 4)      0.86
# 356   RandomForestClassifier(max_depth=5)        0.5   (700, 4)      0.86
# 357   RandomForestClassifier(max_depth=5)        0.5   (700, 4)      0.87
# 358   RandomForestClassifier(max_depth=5)        0.5   (700, 4)      0.86
# 359   RandomForestClassifier(max_depth=5)        0.5   (700, 4)      0.87
#
#      precision  recall  fscore  crossval_acc  false_pos  false_neg
# 0        0.861   0.949   0.903          0.85       0.10       0.03
# 1        0.862   0.956   0.907          0.84       0.10       0.03
# 2        0.859   0.934   0.895          0.85       0.10       0.04
# 3        0.866   0.942   0.902          0.85       0.10       0.04
# 4        0.871   0.934   0.901          0.85       0.09       0.04
# ..         ...     ...     ...           ...        ...        ...
# 355      0.917   0.870   0.893          0.87       0.05       0.09
# 356      0.921   0.865   0.892          0.87       0.05       0.09
# 357      0.922   0.870   0.895          0.86       0.05       0.09
# 358      0.921   0.865   0.892          0.87       0.05       0.09
# 359      0.919   0.883   0.900          0.86       0.05       0.08
#
# [360 rows x 13 columns]

# %% [markdown]
# #### Best random forest model
#
# The best Random Forest reaches:
#
# - accuracy        0.78 +- 0.01
# - precision       0.69 +- 0.03
# - recall          0.61 +- 0.04
# - fscore          0.64 +- 0.02
# - false_pos       0.09 +- 0.01
# - false_neg       0.13 +- 0.02

# %%
resdf.x_shape.unique()
# Out:
# array(['(700, 24)', '(700, 5)'], dtype=object)

# %%
# summary of best random forest
resdf2 = resdf[(resdf.model == 'RandomForestClassifier(max_depth=20)') & (resdf.x_shape=='(700, 24)')]
assert len(resdf2) > 0
desc_df = resdf2.groupby(['var_group','model']).mean().round(2) 
# 'model','accuracy','precision','recall','fscore',
#                  'var_group','false_pos','false_neg']]
#del resdf2
#desc_df = des.model == 'RandomForestClassifier(max_depth=10)'c_df.sort_values(('accuracy'), ascending=False)
desc_df.iloc[1].round(2)
resdf2.mean().round(2)
# Out:
# /var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/3400230315.py:10: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   resdf2.mean().round(2)
# trial_i         4.50
# test_size       0.40
# accuracy        0.78
# precision       0.69
# recall          0.61
# fscore          0.64
# crossval_acc    0.79
# false_pos       0.09
# false_neg       0.13
# dtype: float64

# %%
resdf2.std().round(2)
# Out:
# /var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/1539563589.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   resdf2.std().round(2)
# trial_i         2.90
# test_size       0.08
# accuracy        0.01
# precision       0.03
# recall          0.04
# fscore          0.02
# crossval_acc    0.01
# false_pos       0.01
# false_neg       0.02
# dtype: float64

# %% [markdown]
# #### Best deep learning model
#
# Best model has neurons: [8]; batch size: 32; split .4.
#
# - accuracy                0.80 +- 0.02
# - precision               0.76 +- 0.06
# - recall                  0.59 +- 0.05
# - fscore                  0.66 +- 0.04
# - true_pos                0.20 +- 0.02
# - true_neg                0.60 +- 0.02
# - false_pos               0.07 +- 0.02
# - false_neg               0.14 +- 0.02
# - pos_accuracy            0.76 +- 0.06
# - neg_accuracy            0.82 +- 0.03
# - avg_accuracy            0.79 +- 0.03
#
# Overall, this is the **best model**, slightly better than the random forests (higher accuracy but mostly higher recall and lower false negatives, 4% vs 8%).

# %%
fn = out_folder+'data/analysis/matching_validation/match_validation_model_comparison_deeplearning-v3.xlsx'
resdf = pd.read_excel(fn)

resdf['pos_accuracy'] = round(resdf.true_pos / (resdf.true_pos+resdf.false_pos),3)
resdf['neg_accuracy'] = round(resdf.true_neg / (resdf.true_neg+resdf.false_neg),3)
resdf['avg_accuracy'] = round((resdf['pos_accuracy'] + resdf['neg_accuracy'])/2,3)
resdf['avg_accuracy_rk'] = resdf['avg_accuracy'].rank(ascending=False)
resdf['fscore_rk'] = resdf['fscore'].rank(ascending=False)

resdf = resdf.sort_values(['avg_accuracy_rk','fscore_rk'])

resdf.head(5)
# Out:
#      index      neurons  batch_size  test_size_split    x_shape  accuracy  \
# 365      0          [8]          32              0.3  (700, 35)     0.824
# 189      0          [8]           8              0.3  (700, 35)     0.829
# 202      0     [32, 32]           8              0.3  (700, 35)     0.838
# 394      0  [8, 16, 32]          32              0.3  (700, 35)     0.824
# 429      0          [8]          32              0.4  (700, 35)     0.821
#
#      precision  recall  fscore  true_pos  ...  false_pos  false_neg   loss  \
# 365      0.907   0.542   0.678     0.186  ...      0.019      0.157  0.475
# 189      0.855   0.627   0.723     0.224  ...      0.038      0.133  0.464
# 202      0.837   0.612   0.707     0.195  ...      0.038      0.124  0.667
# 394      0.860   0.589   0.699     0.205  ...      0.033      0.143  0.447
# 429      0.848   0.583   0.691     0.200  ...      0.036      0.143  0.448
#
#      accuracy_train_max  trial  pos_accuracy  neg_accuracy  avg_accuracy  \
# 365               0.822      5         0.907         0.803         0.855
# 189               0.841      9         0.855         0.820         0.837
# 202               0.912      2         0.837         0.838         0.837
# 394               0.863      4         0.861         0.812         0.836
# 429               0.833      9         0.847         0.813         0.830
#
#      avg_accuracy_rk  fscore_rk
# 365              1.0       69.5
# 189              2.5        3.5
# 202              2.5       15.5
# 394              4.0       33.0
# 429              5.0       45.5
#
# [5 rows x 21 columns]

# %%
resdf.groupby(['neurons','batch_size','test_size_split']).mean().round(2).sort_values('avg_accuracy').tail(10)
# Out:
#                                         index  accuracy  precision  recall  \
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                0.0      0.79       0.73    0.58
#                        0.3                0.0      0.79       0.72    0.60
# [8, 16, 32] 32         0.3                0.0      0.79       0.71    0.62
# [8, 16]     32         0.3                0.0      0.80       0.70    0.63
# [8]         32         0.5                0.0      0.79       0.75    0.56
#             1          0.5                0.0      0.80       0.74    0.59
#             8          0.3                0.0      0.80       0.74    0.57
#                        0.4                0.0      0.79       0.77    0.56
#             32         0.3                0.0      0.80       0.73    0.60
#                        0.4                0.0      0.80       0.76    0.59
#
#                                         fscore  true_pos  true_neg  false_pos  \
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                0.64      0.19      0.60       0.07
#                        0.3                0.65      0.20      0.59       0.08
# [8, 16, 32] 32         0.3                0.66      0.20      0.60       0.08
# [8, 16]     32         0.3                0.66      0.19      0.61       0.08
# [8]         32         0.5                0.64      0.19      0.60       0.06
#             1          0.5                0.66      0.19      0.60       0.07
#             8          0.3                0.65      0.19      0.61       0.06
#                        0.4                0.64      0.19      0.61       0.06
#             32         0.3                0.65      0.19      0.61       0.07
#                        0.4                0.66      0.20      0.60       0.07
#
#                                         false_neg  loss  accuracy_train_max  \
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                   0.14  0.57                0.89
#                        0.3                   0.13  0.57                0.88
# [8, 16, 32] 32         0.3                   0.12  0.59                0.88
# [8, 16]     32         0.3                   0.11  0.47                0.85
# [8]         32         0.5                   0.15  0.48                0.83
#             1          0.5                   0.13  0.60                0.87
#             8          0.3                   0.14  0.50                0.84
#                        0.4                   0.15  0.48                0.84
#             32         0.3                   0.13  0.47                0.82
#                        0.4                   0.14  0.47                0.83
#
#                                         trial  pos_accuracy  neg_accuracy  \
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                4.5          0.73          0.81
#                        0.3                4.5          0.72          0.82
# [8, 16, 32] 32         0.3                4.5          0.70          0.83
# [8, 16]     32         0.3                4.5          0.70          0.84
# [8]         32         0.5                4.5          0.75          0.80
#             1          0.5                4.5          0.74          0.82
#             8          0.3                4.5          0.74          0.81
#                        0.4                4.5          0.77          0.80
#             32         0.3                4.5          0.73          0.83
#                        0.4                4.5          0.76          0.82
#
#                                         avg_accuracy  avg_accuracy_rk  \
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                      0.77           148.50
#                        0.3                      0.77           162.95
# [8, 16, 32] 32         0.3                      0.77           178.50
# [8, 16]     32         0.3                      0.77           156.05
# [8]         32         0.5                      0.77           139.80
#             1          0.5                      0.78           116.10
#             8          0.3                      0.78           128.00
#                        0.4                      0.78            91.50
#             32         0.3                      0.78           132.50
#                        0.4                      0.79           105.75
#
#                                         fscore_rk
# neurons     batch_size test_size_split
# [8, 16]     8          0.5                 236.55
#                        0.3                 188.15
# [8, 16, 32] 32         0.3                 170.40
# [8, 16]     32         0.3                 166.05
# [8]         32         0.5                 243.35
#             1          0.5                 169.60
#             8          0.3                 224.35
#                        0.4                 229.10
#             32         0.3                 175.95
#                        0.4                 143.80

# %%
# best DL model stats
best_dl = resdf[(resdf.neurons=='[8]') & (resdf.batch_size==32) & (resdf.test_size_split==.4) ]
print('N =',len(best_dl))
best_dl.mean().round(2)
# Out:
# N = 10
# /var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/103791629.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   best_dl.mean().round(2)
# index                   0.00
# batch_size             32.00
# test_size_split         0.40
# accuracy                0.80
# precision               0.76
# recall                  0.59
# fscore                  0.66
# true_pos                0.20
# true_neg                0.60
# false_pos               0.07
# false_neg               0.14
# loss                    0.47
# accuracy_train_max      0.83
# trial                   4.50
# pos_accuracy            0.76
# neg_accuracy            0.82
# avg_accuracy            0.79
# avg_accuracy_rk       105.75
# fscore_rk             143.80
# dtype: float64

# %%
# best DL model stats
best_dl.std().round(2)
# Out:
# /var/folders/f6/jwz5v525215521t6qbnxcdh80000gn/T/ipykernel_88655/3461951357.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   best_dl.std().round(2)
# index                 0.00
# batch_size            0.00
# test_size_split       0.00
# accuracy              0.02
# precision             0.06
# recall                0.05
# fscore                0.04
# true_pos              0.02
# true_neg              0.02
# false_pos             0.02
# false_neg             0.02
# loss                  0.02
# accuracy_train_max    0.01
# trial                 3.03
# pos_accuracy          0.06
# neg_accuracy          0.03
# avg_accuracy          0.03
# dtype: float64

# %%
resdf.groupby('batch_size').mean().round(2)
# Out:
#             index  test_size_split  accuracy  precision  recall  fscore  \
# batch_size
# 1             0.0              0.4      0.77       0.66    0.60    0.63
# 8             0.0              0.4      0.77       0.68    0.59    0.63
# 32            0.0              0.4      0.78       0.69    0.60    0.64
#
#             true_pos  true_neg  false_pos  false_neg  loss  \
# batch_size
# 1               0.20      0.57       0.10       0.13  2.05
# 8               0.19      0.58       0.09       0.13  1.27
# 32              0.19      0.59       0.09       0.13  0.93
#
#             accuracy_train_max  trial  pos_accuracy  neg_accuracy  \
# batch_size
# 1                         0.94    4.5          0.66          0.81
# 8                         0.93    4.5          0.68          0.81
# 32                        0.91    4.5          0.69          0.82
#
#             avg_accuracy  avg_accuracy_rk  fscore_rk
# batch_size
# 1                   0.74           306.66     285.12
# 8                   0.75           268.36     276.63
# 32                  0.75           236.48     249.75

# %%
resdf.groupby('neurons').mean().round(2)
# Out:
#                index  batch_size  test_size_split  accuracy  precision  \
# neurons
# [256, 512]       0.0       13.67              0.4      0.76       0.63
# [32, 32]         0.0       13.67              0.4      0.77       0.68
# [32, 64, 512]    0.0       13.67              0.4      0.75       0.63
# [8, 16, 32]      0.0       13.67              0.4      0.78       0.68
# [8, 16]          0.0       13.67              0.4      0.79       0.70
# [8]              0.0       13.67              0.4      0.79       0.74
#
#                recall  fscore  true_pos  true_neg  false_pos  false_neg  loss  \
# neurons
# [256, 512]       0.60    0.61      0.20      0.56       0.12       0.13  2.53
# [32, 32]         0.60    0.64      0.20      0.58       0.09       0.13  1.17
# [32, 64, 512]    0.60    0.61      0.20      0.56       0.12       0.13  2.57
# [8, 16, 32]      0.61    0.64      0.20      0.58       0.09       0.13  1.07
# [8, 16]          0.60    0.64      0.20      0.59       0.09       0.13  0.64
# [8]              0.58    0.65      0.19      0.60       0.07       0.14  0.52
#
#                accuracy_train_max  trial  pos_accuracy  neg_accuracy  \
# neurons
# [256, 512]                   0.99    4.5          0.63          0.81
# [32, 32]                     0.94    4.5          0.68          0.81
# [32, 64, 512]                0.99    4.5          0.63          0.81
# [8, 16, 32]                  0.91    4.5          0.68          0.82
# [8, 16]                      0.88    4.5          0.70          0.82
# [8]                          0.85    4.5          0.74          0.81
#
#                avg_accuracy
# neurons
# [256, 512]             0.72
# [32, 32]               0.75
# [32, 64, 512]          0.72
# [8, 16, 32]            0.75
# [8, 16]                0.76
# [8]                    0.77

# %% [markdown]
# ## Run deep learning on all museums
#
# Using the best deep learning model defined above, find indicators for all museums (from websites and social media).
#
# ### Build best DL model
#
# {'neurons': ['[8]'],
#  'batch_size': [32],
#  'test_size_split': [0.4],
#  'x_shape': ['(700, 33)'],
#  'accuracy': [0.825],
#  'precision': [0.783],
#  'recall': [0.677],
#  'fscore': [0.726],
#  'true_pos': [0.232],
#  'true_neg': [0.593],
#  'false_pos': [0.064],
#  'false_neg': [0.111],
#  'loss': [0.423],
#  'accuracy_train_max': [0.824]}

# %%
# build best model: neurons: [8,16]; batch size: 8; split .3.

# call model fit with callbacks=[early_stopping_monitor]

valid_ann_df_fn = 'matches_valid_ann_df_v3.pik'
valid_ann_df = pd.read_pickle(out_folder+'data/annotations/'+valid_ann_df_fn)

old_metric = 0
eval_stats = None
for i in range(20):
    print("-"*30)
    eval_df, model, columns = run_deep_learning(valid_ann_df, .4, [8], 32, early_stopping_monitor)
    metric = eval_df['fscore'][0]
    print('fscore', metric)
    if old_metric < metric:
        fn = out_folder+'tmp/matching_validation_deep_learning_model.h5'
        model.save(fn)
        print('model columns:',columns)
        fn_cols = out_folder+'tmp/matching_validation_deep_learning_model_columns.csv'
        columns.to_series().to_csv(fn_cols,index=False)
        print('saved in',fn)
        eval_stats = eval_df
        old_metric = metric

print('best model')
eval_stats
# Out:
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7892857193946838
# fscore 0.609
# model columns: Index(['sem_similarity', 'token_n', 'lemma_n', 'ann_overlap_lemma',
#        'ann_overlap_token', 'example_len', 'txt_overlap_lemma',
#        'txt_overlap_token', 'ann_overlap_criticwords', 'lemmatoken_n',
#        'ann_overlap_tokenlemma', 'txt_overlap_tokenlemma',
#        'indicator_code_closed_indef', 'indicator_code_closed_perm',
#        'indicator_code_finance_health', 'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working'],
#       dtype='object')
# saved in ../../tmp/matching_validation_deep_learning_model.h5
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7964285612106323
# fscore 0.685
# model columns: Index(['sem_similarity', 'token_n', 'lemma_n', 'ann_overlap_lemma',
#        'ann_overlap_token', 'example_len', 'txt_overlap_lemma',
#        'txt_overlap_token', 'ann_overlap_criticwords', 'lemmatoken_n',
#        'ann_overlap_tokenlemma', 'txt_overlap_tokenlemma',
#        'indicator_code_closed_indef', 'indicator_code_closed_perm',
#        'indicator_code_finance_health', 'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working'],
#       dtype='object')
# saved in ../../tmp/matching_validation_deep_learning_model.h5
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7928571701049805
# fscore 0.628
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7928571701049805
# fscore 0.646
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.8035714030265808
# fscore 0.689
# model columns: Index(['sem_similarity', 'token_n', 'lemma_n', 'ann_overlap_lemma',
#        'ann_overlap_token', 'example_len', 'txt_overlap_lemma',
#        'txt_overlap_token', 'ann_overlap_criticwords', 'lemmatoken_n',
#        'ann_overlap_tokenlemma', 'txt_overlap_tokenlemma',
#        'indicator_code_closed_indef', 'indicator_code_closed_perm',
#        'indicator_code_finance_health', 'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working'],
#       dtype='object')
# saved in ../../tmp/matching_validation_deep_learning_model.h5
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.824999988079071
# fscore 0.684
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7571428418159485
# fscore 0.609
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7964285612106323
# fscore 0.632
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.8214285969734192
# fscore 0.688
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.824999988079071
# fscore 0.726
# model columns: Index(['sem_similarity', 'token_n', 'lemma_n', 'ann_overlap_lemma',
#        'ann_overlap_token', 'example_len', 'txt_overlap_lemma',
#        'txt_overlap_token', 'ann_overlap_criticwords', 'lemmatoken_n',
#        'ann_overlap_tokenlemma', 'txt_overlap_tokenlemma',
#        'indicator_code_closed_indef', 'indicator_code_closed_perm',
#        'indicator_code_finance_health', 'indicator_code_funding_did_not_get',
#        'indicator_code_funding_fundraise', 'indicator_code_funding_gov_emer',
#        'indicator_code_funding_other_emer', 'indicator_code_lang_difficulty',
#        'indicator_code_made_covid_safe', 'indicator_code_online_engag',
#        'indicator_code_online_event', 'indicator_code_online_exhib',
#        'indicator_code_open_cafe', 'indicator_code_open_cur',
#        'indicator_code_open_onlineshop', 'indicator_code_project_postpone',
#        'indicator_code_reopen_intent', 'indicator_code_reopen_plan',
#        'indicator_code_staff_hiring', 'indicator_code_staff_restruct',
#        'indicator_code_staff_working'],
#       dtype='object')
# saved in ../../tmp/matching_validation_deep_learning_model.h5
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.800000011920929
# fscore 0.646
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.824999988079071
# fscore 0.696
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7821428775787354
# fscore 0.659
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7607142925262451
# fscore 0.562
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.800000011920929
# fscore 0.632
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.8214285969734192
# fscore 0.675
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.7642857432365417
# fscore 0.629
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.800000011920929
# fscore 0.674
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.8214285969734192
# fscore 0.684
# ------------------------------
# run_deep_learning (700, 44) 0.4 [8] 32
# build_convolutional_nn:  33 [8]
# -> acc  0.8178571462631226
# fscore 0.687
# best model
# {'neurons': ['[8]'],
#  'batch_size': [32],
#  'test_size_split': [0.4],
#  'x_shape': ['(700, 33)'],
#  'accuracy': [0.825],
#  'precision': [0.783],
#  'recall': [0.677],
#  'fscore': [0.726],
#  'true_pos': [0.232],
#  'true_neg': [0.593],
#  'false_pos': [0.064],
#  'false_neg': [0.111],
#  'loss': [0.423],
#  'accuracy_train_max': [0.824]}

# %% [markdown]
# End of notebook
