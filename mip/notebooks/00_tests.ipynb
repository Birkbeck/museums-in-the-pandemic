# %% [markdown]
# # Museums in the Pandemic - 00 tests
#
# **Author**: Andrea Ballatore (Birkbeck, University of London)
#
# **Abstract**: notebook for testing
#
# ## Setup
# This is to check that your environment is set up correctly (it should print 'env ok', ignore warnings).

# %%
# Test geospatial libraries
# check environment
import os
print("Conda env:", os.environ['CONDA_DEFAULT_ENV'])
if os.environ['CONDA_DEFAULT_ENV'] != 'mip_v1':
    raise Exception("Set the environment 'mip_v1' on Anaconda. Current environment: " + os.environ['CONDA_DEFAULT_ENV'])

# spatial libraries 
import pandas as pd
import pickle
from termcolor import colored
import sys
import spacy
import numpy as np
#import tensorflow as tf
from bs4 import BeautifulSoup
from bs4.element import Comment
#import torch
import matplotlib.pyplot as plt

# import from `mip` project
print(os.getcwd())
fpath = os.path.abspath('../')
if not fpath in sys.path:
    sys.path.insert(0, fpath)

out_folder = '../../'
    
print('env ok')
# Out:
# Conda env: mip_v1
# C:\Users\VV\workspace1\museums-in-the-pandemic\mip\notebooks
# env ok

# %% [markdown]
# # Museum text analytics

# %% [markdown]
# ## Model1: Vectorise text from museum websites

# %% [markdown]
# ### Connect to DB

# %%
# open connection to DB
from db.db import connect_to_postgresql_db

db_conn = connect_to_postgresql_db()
print("DB connected")
# Out:
# DB connected

# %% [markdown]
# ### Setup spacy NLP

# %%
# install language model
# !python -m spacy download en_core_web_sm
# Note: if this cell does not work, run the same command 
#       without "!" in the Anaconda terminal
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from en_core_web_sm==2.3.1) (2.3.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.55.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.25.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: setuptools in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (51.3.3.post20210118)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vv\anaconda3\envs\mip_v1\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# set up the spacy environment
import spacy
from spacy import displacy
from collections import Counter
spacy.prefer_gpu()
# load language model
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
# Spacy stopwords
all_stopwords = nlp.Defaults.stop_words

# %%
# get text from websites

from analytics.an_websites import get_attribute_for_webpage_url

session_id = '20210420'
test_urls = ['https://www.britishmuseum.org/']
attrib_name = 'all_text' # 'title'

for url in test_urls:
    print(url)
    res = get_attribute_for_webpage_url(url, session_id, attrib_name, db_conn)
    if not res: continue
    print(res)
    blocks = res.split("\n")
    print("LEN", len(blocks))
    print(blocks)
# Out:
# https://www.britishmuseum.org/
# Skip to main content Please enable JavaScript in your web browser to get the best experience. We use cookies to make our website work more efficiently, to provide you with more personalised services or advertising to you, and to analyse traffic on our website. For more information on how we use cookies and how to manage cookies, please follow the 'Read more' link, otherwise select 'Accept and close'. Read more about our cookie policy Accept and close the cookie policy Menu Main navigation Visit Toggle Visit submenu Back
# to previous menu —
# Visit —
# Visit —
# Family visits —
# Group visits —
# Audio guide —
# Out-of-hours tours —
# Tours and talks —
# Object trails —
# Accessibility —
# Food and drink —
# Late opening on Fridays —
# Museum map Exhibitions and events Collection Toggle Collection submenu Back
# to previous menu —
# Collection —
# Collection —
# Collection online —
# Galleries —
# Blog —
# Audio tour highlights —
# The British Museum podcast Learn Toggle Learn submenu Back
# to previous menu —
# Learn —
# Learn —
# Schools —
# Communities —
# Adult learning —
# Young people Membership Toggle Membership submenu Back
# to previous menu —
# Membership —
# Membership —
# Renew Membership —
# Events —
# Buy Membership —
# Renew Gift Membership —
# Existing Members —
# Buy Under 26 Membership —
# Upgrade your Membership —
# How your money helps —
# Buy Gift Membership —
# Visiting as a Member —
# Members' Room Support us Toggle Support us submenu Back
# to previous menu —
# Support us —
# Donate —
# Corporate support —
# Become a Patron —
# Supporter case studies —
# Become a Volunteer —
# Leave a legacy —
# American Friends of the British Museum Secondary navigation Shop Search Donate Hide menu The British Museum Stay connected We're planning to reopen in May – until then you can explore the Museum online. Find out more Show image caption Close image caption The Great Court at the British Museum. Explore the Great Court Discover two million years of human history and culture Free entry The Museum is closed Exhibitions and events See all exhibitions and events Thomas Becket murder and the making of a saint . Coming soon
# . Exhibition Coming soon Reflections
# contemporary art of the Middle East and North Africa . Coming soon
# . Exhibition Coming soon We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations. More ways to enjoy the Museum from home Take a virtual gallery tour Explore the Museum's galleries from home and get closer to the collection, using Google Street View. Fill your bookshelves this spring Dive into a new novel, brush up on your history or leaf through exhibition catalogues in our online bookshop. Objects in 3D See some of our most popular objects from every angle on Sketchfab, including mummy masks and the Rosetta Stone. Traverse our object timeline From ancient handaxes to a penny defaced by suffragettes, travel through thousands of years of history in an audio tour of popular objects. Sign up to our newsletters Stay connected and receive all our latest news, online events and ways to visit the Museum from home. Sign up Support the Museum Become a Member Support us by becoming a Member today and get 10% off in our online shop. Donate Your support is vital and helps the Museum to share the collection with the world. Shop online The British Museum shop has a range of unique gifts, replicas, games and more. 10% off for Members Become a Member and enjoy a 10% discount at all of the Museum's shops. Visit the online shop Explore the collection See all Egypt Read more Desire, love and identity Read the blog Animals See the collection Americas See the collection Death and memory Read more Africa See the collection Welcome to the British Museum Shop Shop now Inspired by the Museum https://www.britishmuseumshoponline.org/inspired-by/inspired-by-the-british-mus... Inspired by the Lewis Chessmen https://www.britishmuseumshoponline.org/inspired-by/lewis-chessmen-collection.h... Inspired by Sutton Hoo https://www.britishmuseumshoponline.org/inspired-by/sutton-hoo.html Inspired by London https://www.britishmuseumshoponline.org/inspired-by/inspired-by-london.html Inspired by cats https://www.britishmuseumshoponline.org/inspired-by/inspired-by-cats.html Inspired by Hokusai https://www.britishmuseumshoponline.org/inspired-by/inspired-by-hokusai.html Inspired by ancient Egypt https://www.britishmuseumshoponline.org/inspired-by/ancient-egypt.html Connect with us Enter your email address to receive our newsletter Facebook Twitter Instagram Youtube weibo wechat . Opens a pop-up detailing how to access wechat. Close wechat Scan the QR code to be taken to WeChat. Back to the top Free entry Great Russell Street
# London WC1B 3DG +44 (0)20 7323 8000 Opening hours The Museum is closed. Footer About us Governance The British Museum story Jobs Press Contact us Visit Museum map Exhibitions and events Accessibility Food and drink Audio guide Commercial Commercial hire Filming Travel trade tours British Museum Press BM Images Our work Departments National International How to borrow Research Research projects Research publications Scientific studies Resources Study rooms Library and archive Search the collection Blog Footer Legal Links Privacy policy Cookies Accessibility Statement Terms of use Modern Slavery Act Statement Chinese site 中文 © 2021
# The Trustees of the British Museum
# LEN 57
# ["Skip to main content Please enable JavaScript in your web browser to get the best experience. We use cookies to make our website work more efficiently, to provide you with more personalised services or advertising to you, and to analyse traffic on our website. For more information on how we use cookies and how to manage cookies, please follow the 'Read more' link, otherwise select 'Accept and close'. Read more about our cookie policy Accept and close the cookie policy Menu Main navigation Visit Toggle Visit submenu Back", 'to previous menu —', 'Visit —', 'Visit —', 'Family visits —', 'Group visits —', 'Audio guide —', 'Out-of-hours tours —', 'Tours and talks —', 'Object trails —', 'Accessibility —', 'Food and drink —', 'Late opening on Fridays —', 'Museum map Exhibitions and events Collection Toggle Collection submenu Back', 'to previous menu —', 'Collection —', 'Collection —', 'Collection online —', 'Galleries —', 'Blog —', 'Audio tour highlights —', 'The British Museum podcast Learn Toggle Learn submenu Back', 'to previous menu —', 'Learn —', 'Learn —', 'Schools —', 'Communities —', 'Adult learning —', 'Young people Membership Toggle Membership submenu Back', 'to previous menu —', 'Membership —', 'Membership —', 'Renew Membership —', 'Events —', 'Buy Membership —', 'Renew Gift Membership —', 'Existing Members —', 'Buy Under 26 Membership —', 'Upgrade your Membership —', 'How your money helps —', 'Buy Gift Membership —', 'Visiting as a Member —', "Members' Room Support us Toggle Support us submenu Back", 'to previous menu —', 'Support us —', 'Donate —', 'Corporate support —', 'Become a Patron —', 'Supporter case studies —', 'Become a Volunteer —', 'Leave a legacy —', "American Friends of the British Museum Secondary navigation Shop Search Donate Hide menu The British Museum Stay connected We're planning to reopen in May – until then you can explore the Museum online. Find out more Show image caption Close image caption The Great Court at the British Museum. Explore the Great Court Discover two million years of human history and culture Free entry The Museum is closed Exhibitions and events See all exhibitions and events Thomas Becket murder and the making of a saint . Coming soon", '. Exhibition Coming soon Reflections', 'contemporary art of the Middle East and North Africa . Coming soon', ". Exhibition Coming soon We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations. More ways to enjoy the Museum from home Take a virtual gallery tour Explore the Museum's galleries from home and get closer to the collection, using Google Street View. Fill your bookshelves this spring Dive into a new novel, brush up on your history or leaf through exhibition catalogues in our online bookshop. Objects in 3D See some of our most popular objects from every angle on Sketchfab, including mummy masks and the Rosetta Stone. Traverse our object timeline From ancient handaxes to a penny defaced by suffragettes, travel through thousands of years of history in an audio tour of popular objects. Sign up to our newsletters Stay connected and receive all our latest news, online events and ways to visit the Museum from home. Sign up Support the Museum Become a Member Support us by becoming a Member today and get 10% off in our onlin ...

# %% [markdown]
# ### Preprocess text

# %%
def spacy_extract_tokens(text):
    """ 
    @returns data frame with tokens with POS, lemma, stop words
    """
    tokens_df = pd.DataFrame()
    text_sentences = nlp(text)
    sent_id = 0
    # segment sentences
    for sentence in text_sentences.sents:
        sent_id += 1
        # for each sentence
        snt_text = sentence.text
        pos_df = pd.DataFrame()
        #print(colored('>', 'red'), snt_text)
        for token in sentence:
            # for each token
            tokens_df = tokens_df.append(pd.DataFrame(
                {"sentence_id": sent_id, "token":token.text, 'lemma':token.lemma_,
                 "pos_tag":token.pos_, 'is_stop': token.is_stop}, 
                index=[0]), ignore_index=True)
    return tokens_df

test_texts = ["""We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations."""]

for tt in test_texts:
    print(tt)
    print("")
    df = spacy_extract_tokens(tt)
    print("Tokens N =",len(df))
    fout = out_folder+'tmp/museum_text_tokens.csv'
    df.to_csv(fout, index=False)
    print("See tokens in",fout)
# Out:
# We need your support Your support is vital and helps the Museum to share the collection with the world. Make a donation What's online... The flowers of Mary Delany 233 years after her death, Delany's detailed floral collages still delight and inspire. Take a closer look at her work in the collection. How to explore the British Museum from home Whether it's a behind-the-scenes podcast or a closer look at our galleries, here are 10 ways to explore the Museum while we're closed. British histories beyond 'Bridgerton' Inspired by the hit Netflix show, watch a panel discussion exploring the reality behind the fantasy of 'Bridgerton'. Discover the Maya World Take a trip to Mexico and explore a wealth of content from the Maya Research Project, including stories, videos and 3D explorations.
#
# Tokens N = 155
# See tokens in ../../tmp/museum_text_tokens.csv

# %% [markdown]
# ### Annotations

# %%
# extract tokens from annotations
from analytics.text_models import get_indicator_annotations

indic_df, ann_df = get_indicator_annotations("../../")
ann_df
# Out:
#                                           text_phrases   indicator_code  \
# 0                                          Closed now        closed_cur
# 1    closed to members of the public until further ...       closed_cur
# 2                         closed until further notice        closed_cur
# 3                            closed until Spring 2021        closed_cur
# 4                        Closed: Until further notice        closed_cur
# ..                                                 ...              ...
# 146            Bailiffgate is now closed due to Covid.       closed_cur
# 147                              Visit our online shop  open_onlineshop
# 148  The new stunning Felton Group online exhibitio...     online_exhib
# 149  Stay up to date with what's happening at Baili...     online_engag
# 150            Find out how we've made your visit safe  made_covid_safe
#
#     indicator_attributes  notes  example_id
# 0                    NaN    NaN           0
# 1                    NaN    NaN           1
# 2                    NaN    NaN           2
# 3                    NaN    NaN           3
# 4                    NaN    NaN           4
# ..                   ...    ...         ...
# 146                  NaN    NaN         146
# 147                  NaN    NaN         147
# 148         _description    NaN         148
# 149                  NaN    NaN         149
# 150                  NaN    NaN         150
#
# [151 rows x 5 columns]

# %%
ann_tokens_df = pd.DataFrame()

for index, row in ann_df.iterrows():
    txt = str(row['text_phrases']).strip()
    df = spacy_extract_tokens(txt)
    #print(df)
    df['example_id'] = row['example_id']
    df['indicator_code'] = row['indicator_code']
    ann_tokens_df = pd.concat([ann_tokens_df, df])

# output annotations tokens
fout = out_folder+'tmp/test_annotations_tokens.csv'
ann_tokens_df.to_csv(fout, index=False)
print(fout)
# Out:
# > Closed now
# > closed to members of the public until further notice.
# > closed until further notice
# > closed until Spring 2021
# > Closed: Until further notice
# > Currently Closed
# > Currently we are closed due to Covid restrictions
# > had to close its doors
# > Murton Park is now closed for the Winter season
# > Museum closed
# > temporally closed
# > The Gallery is now closed for winter.
# > There will be no services over the Christmas period due to the Covid-19 pandemic
# > to temporarily close
# > we have closed [the railway]
# > We’re closed
# > now closed for the foreseeable future
# > dismantling of some of our displays
# > scheduled to be re-located in the near future
# > SUSPEND ALL MUSEUM EVENTS for the foreseeable future
# > will close from 28 February 2021 for the foreseeable future
# > We will be however be open in December for the Santa’s Staycation event
# > completely making up for the deficit caused by the 2020 Covid lockdown, and enables us to continue with confidence.
# > The Scottish Fisheries Museum in Anstruther has secured vital funds of over £100,000 through the Museum Galleries Scotland Recovery and Resilience Fund
# > We are therefore keeping our Survival Appeal open and have increased our target to £200,000.
# > We have now exceeded our original £100,000 target
# > we remain optimistic in finding new institutional support for our unique work.
# > a successful crowdfunding campaign was launched
# > consider donating to our Rose Walk 50 Campaign.
# > |we want to mark this very strange year and create a space of hope in the Walled Garden for you
# > Crowdfunding appeal, and enabled us to exceed our £6,000 target
# > The total amount raised online was £6,180, and in addition several donations were received in the form of a cheque.
# > crowdfunding project for which we are aiming to raise £10,000| Chasewater Railway Pandemic Survival
# > Donate Her  to help us re-open in 2021
# > In less than two months you have helped us to reach our target and raised over £45,000 to support the work of The Jenner Trust.
# > Jane Austen's House has launched our Survival Appeal, | calling on our worldwide community to help if they can.
# > Just Giving page to help secure the Gallery for the future
# > Please donate NOW to help the Florence Nightingale Museum survive.
# > please support our Survival Appeal
# > So, we’re asking for your help in the form of this new donations page.
# > Our income is not coming in, but our outgoings are still going out – so
# > we need your help to keep us afloat this season, to ensure we come back once this situation is over and continue to keep the age of steam alive for generations to come!
# > Survival Appeal
# > Target £200,000 | Raised
# > so far £129,625
# > Thank you to everyone who supported our campaigns to #SaveCharleston and #ReopenCharleston.
# > The struggles that we faced in 2020 have not gone away and as winter takes hold vital maintenance work has to continue to protect the site.
# > Updated January 8th 2021.
# > We urgently need to raise £1 million to cover the shortfall from severely reduced visitor numbers and loss of income from gift shops, cafes and events due to the Covid 19 crisis.
# > We've done it!
# > 17/06/2020
# > You did it!
# > Scottish Fisheries Museum “Weathering the Storm” through funding success - 04 December 2020.
# > The Scottish Fisheries Museum in
# > Anstruther has secured vital funds of over £100,000 through the Museum Galleries Scotland Recovery and Resilience Fund
# > ALL the Trust's operating income comes from admissions to our sites, spending in our shops and cafes and from donations
# > Although we have applied for many, we have not received any grants to help us
# > Due to not receiving support from the UK Government
# > External financial support has been essential and extremely welcome
# > no core Government funding
# > We have been overlooked for grant funding
# > during this difficult time,
# > major review and restructuring of its operations in response to the damaging and continuing effects of the pandemic.
# > The COVID-19 pandemic is a disaster for individuals, businesses and organisations around the world.
# > For us, as for so many, it will be crippling.
# > The impact it will have on our ability to protect this special place could be too much.
# > It is with this in mind that Jane Austen's House has launched our Survival Appeal, calling on our worldwide community to help if they can.
# > The museum is almost entirely reliant on income from our visitors in the form of ticket sales, shop purchases and donations.
# > This now looks to be at risk
# > The struggles that we faced in 2020
# > towards keeping the railway alive.
# > We are all working our hardest to keep the doors open, but
# > the sad reality is that we are going to struggle over the winter months
# > we have had to make some changes in order for us to survive.
# > we need your help to keep us afloat
# > this difficult and challenging year.
# > and difficult times and
# > we remain hopeful for better news soon
# > is extremely short of money given what must be done and now the virus outbreak makes this years outlook very uncertain indeed
# > This is a critical time
# > a very challenging time.
# > and our properties are at risk of permanent closure,
# > Trying to operate a Museum during the pandemic is extremely challenging
# > during this difficult time,
# > huge hole in our funds and a threatened our future
# > blog pages, which are regularly updated
# > Online Engagement Programme - 20th February 2021
# > Start:
# > Saturday 20 February 2021 10:00
#
# > End:
# > Sunday 28 February 2021 16:00
# > End: Sunday 28 February 2021 16:00
# > Subscribe to Charleston's e-newsletter
# > the Long Shop Museum would love to hear about your personal experiences during this pandemic
# > Blog tab
# > follow us on Facebook, Instagram or find us on Flickr to see regular updates on the renovation.
# > online events
# > Kipper the Cat’s Gansey Comic and Colouring Competition!
# > Sunday, 31st January 2021 10:00 AM
# > Bloomsbury at home: buy all 5
# > Tickets are now on sale for our winter lecture series
# > The Houses of the Sussex Downs: A Sussex Archaeology at Home Lecture by Dr Sue Berry
# > Live Online
# > 21/01/2021
# > Forthcoming events Becoming a Scientist:
# > Discovery Day at Home
# > Shire Hall: 150 Years of Courtroom Drama
# > *Online Event*
# > Thursday 4th February 7pm
# > Online: Jane Austen’s Artful Letters
# > 29 Sep — 31 Dec 2021
# > nan
# > Online:
# > A Choice Collection of Curiosities Comically Created from
# > Chawton Cottage 28 Oct
# > — 31 Dec 2021
# > Online:
# > Jane Austen Gingerbread Gallery 25 Nov — 6 Jan 2021
# > Our online exhibition Sea Change also includes lots of ideas for activities, both on and off-line.
# > our café is open
# > pre-book tickets before visiting
# > From July 2020, Charleston’s garden is open for pre-booked visits
# > Our Chasewater Railway Model Shop will be offering online sales only with a click & collect and delivery service available
# > Our web shop continues to ship to customers worldwide with a fantastic range of souvenirs, or gifts to say thanks
# > All purchases will be processed and dispatched on or after Wednesday 20 January
# > Online shop
# > Enjoy our exclusive range of Grayson Perry merchandise in our shop
# > Our online shop remains open
# > Due to COVID19 the Museum Woodland Trail project was postponed in February 2020
# > we have taken the decision to postpone the planned 2020 opening of
# > 2021 Dates Coming Soon!
# > 2021 Operation Running Dates
# > closed until Spring 2021
# > Event dates for 2021 will be posted here shortly.
# > In the meantime, keep an eye on the website and follow us on Facebook and/or Instagram @bucksrailcentre where we will announce any tickets going on sale.
# > look forward to welcoming you again soon
# > look forward to welcoming you back
# > Open: As soon as possible
# > Our hopes for 2021
# > please book your ticket online when we re-open
# > re-open in 2021
# > updates about reopening,
# > Visit us in 2021We will constantly monitor the situation and look to reopen
# > we can re-open
# > we have closed [the railway] until at least the end of June
# > We hope and pray that we can bring some of our amazing special events to you in 2021,
# > We hope to announce and bring you the journey from Oswestry to Weston during 2021
# > we look forward to seeing you again in 2021
# > We look forward to welcoming you all to Louth Museum when we open for the 2021 season.
# > we still hope to mark our next anniversary
# > welcome visitors back to our site as soon as we are able to
# > welcome you back in spring 2021!
# > welcoming you back soon.
# > will reopen fully in Spring.
# > We plan to reopen for the 2021 season on March 6th.
# > planning to reopen December 2020
# > We are hiring new volunteers.
# > Click here to find out more about these posts
# > Current vacancies:
# > Woodland Trail Project Manager
# > We also have a real need for more volunteers
# > major review and restructuring of its operations in response to the damaging and continuing effects of the pandemic.
# > The curatorial team continues to work through the winter months.
# > Our phones, emails and social media messages will continue to be checked throughout the closure
# > We look forward to seeing you soon
# > We are currently closed to visitors
# > Once Government restrictions are lifted, we look forward to seeing you back at the museum!
# > Opening times
# > Once Covid-restrictions are lifted Wednesday - Sunday 10am to 4pm
# > support the musueum and make a donation today
# > Please note: Bailiffgate is curently closed due to Government Covid restrictions
# > our office wil not reopen till 5th January.
# > You can, however purchase a wide range of unique gifts from our online shop.
# > Bailiffgate is now closed due to Covid.
# > Visit our online shop
# > The new stunning Felton Group online exhibition is now live
# > Stay up to date with what's happening at Bailiffgate Museum and Gallery
# > Find out how we've made your visit safe
# ../../tmp/test_annotations_tokens.csv

# %%
from museums import get_museums_w_web_urls
from analytics.an_websites import get_attribute_for_webpage_url
df= get_museums_w_web_urls("../../")

datadict={}
session_id='20210614'
attrib_name = 'all_text'
for index, row in df.iterrows():
    datadict[row['muse_id']]=get_attribute_for_webpage_url(row['url'], session_id, attrib_name, db_conn)
tokeniseddict={}
for key, value in datadict.items():
    if value is not None:
        tokeniseddict[key]=spacy_extract_tokens(value)
data_items = tokeniseddict.items()
data_list = list(data_items)
print(tokeniseddict)
datadf=pd.DataFrame(data_list)
datadf.to_csv('../../tmp/a_x_test2.tsv', sep='\t')
# Out:
# C:\Users\VV\anaconda3\envs\mip_v1\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# museums urls: ../../data/museums/museum_websites_urls-v3.tsv
# get_museums_w_web_urls Museums=3344 URLs=3344
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.100bgmus.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.english-heritage.org.uk/visit/places/1066-battle-of-hastings-abbey-and-battlefield/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.doningtonleheath.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.rbkc.gov.uk/subsites/museums/18staffordterrace.aspx' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.19princeletstreet.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitswanseabay.com/listings/1940s-swansea-bay-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/2-willow-road' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.museums.gov.gg/squadron201' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://traquo.com/251-menlove-avenue-liverpool/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.306bg.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitnorfolk.co.uk/Wymondham-389th-Bomb-Group-Memorial-Exhibition/details/?dms=3&venue=0510257' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://390th.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/575-wandsworth-road' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://602squadronmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.78derngate.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://9th12thlancersmuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/a-la-ronde' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.discovercarlisle.co.uk/See-Do/a-world-in-miniature-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://museumsandgalleries.leeds.gov.uk/abbey-house-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.abbeypumpingstation.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.simt.co.uk/abbeydale-industrial-hamlet' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://lakelandarts.org.uk/abbot-hall/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.scottsabbotsford.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitcaerphilly.com/aber-valley-heritage-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/aberconwy-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.aagm.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.aberdeencity.gov.uk/AAGM/plan-your-visit/aberdeen-maritime-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://aberdeensciencecentre.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.livelifeaberdeenshire.org.uk/museums/find-a-museum/aberdeenshire-farming-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.abergavennymuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.abertilleryanddistrictmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://ceramics-aberystwyth.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.abingdon.gov.uk/partners/abingdon-county-hall-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.northamptonshiresurprise.com/organisation/abington-park-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.actoncourt.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.actonscott.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.rhqagc.com/museum.html' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.adlingtonhall.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://aerospacebristol.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.agriculturalmuseumbrook.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www2.humboldt.edu/scimus/BalanceExhibit/Ains_Cat_A10_1940/AinsCat_40.htm' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.paradata.org.uk/article/airborne-assault-museum-iwm-duxford' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.english-heritage.org.uk/visit/places/aldborough-roman-site/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://aldbourneheritage.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.aldeburghmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.alderneysociety.org/museum.php' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.hampshireculture.org.uk/aldershot-military-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.amrtm.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.imperial.nhs.uk/about-us/who-we-are/fleming-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.english-heritage.org.uk/visit/places/alexander-keiller-museum-avebury/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://alfordheritagemuseum.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.alfordmanorhouse.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.undiscoveredscotland.co.uk/alford/railwaymuseum/index.html' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://alfredcorry.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.kettering.gov.uk/gallery' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/alfriston-clergy-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ahbtt.org.uk/visit/crypt/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.hampshireculture.org.uk/allen-gallery' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.allertoncastle.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.honitonmuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.almondvalley.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.alnvalleyrailway.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.alnwickcastle.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.alstonefield.org/tourist-info/geology/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://spencerofalthorp.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.culturepk.org.uk/museums-and-galleries/alyth-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.amberleymuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.brownlowhouse.com/brownlow-hq-museum.html' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.fairorganmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://amershammuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.ceredigionmuseum.wales/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.culture24.org.uk/mw1400' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.aniodhlann.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://anaesthetists.org/Home/Heritage-centre' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.abdn.ac.uk/suttie-centre/anatomy/museum.php' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ed.ac.uk/biomedical-sciences/anatomy/anatomical-museum/visit-us' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.staffordbc.gov.uk/the-ancient-high-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.museums.norfolk.gov.uk/ancient-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.hampshireculture.org.uk/andover-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.carnegiebirthplace.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://discovernorthernireland.com/things-to-do/andrew-jackson-cottage-and-us-rangers-centre-p674931' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://andrewloganmuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.loyalistconflictmuseum.com/about' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/anglesey-abbey-gardens-and-lode-mill' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.maryandcuthbert.org.uk/parish-church-/ankers-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.annan.org.uk/museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.shakespeare.org.uk/visit/anne-hathaways-cottage/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://sussexpast.co.uk/properties-to-discover/anne-of-cleves-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://antiquebreadboards.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/antony' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.apedale.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.applecrossheritage.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.english-heritage.org.uk/visit/places/apsley-house/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://arbeiaromanfort.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://visitangus.com/arbroath-signal-tower-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://arburyestate.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitscotland.com/info/see-do/arbuthnot-museum-p246841' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://maritimehull.co.uk/projects/the-arctic-corsair' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ardingtonhouse.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/ardress-house' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.argylls.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.arleyhallandgardens.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/arlington-court-and-the-national-trust-carriage-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.armadalecastle.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://visitarmagh.com/places-to-explore/armagh-county-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://armaghrobinsonlibrary.co.uk/wp/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://armitt.com/armitt_website/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.armourgeddon.co.uk/Military-Vehicle-Museum-Entry.html' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://arnistonhouse.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.arranmuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.arsenal.com/history/the-arsenal-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://discovernorthernireland.com/things-to-do/arthur-cottage-and-interpretative-centre-p687131' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.arundelcastle.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://arundelmuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://arundells.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/ascott' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.ashmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://ashbourneheritagesociety.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://ashburtonmuseum.co.nz/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ashbydelazouch.info/Ashby-Museum.aspx' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.ashdonvillagemuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://ashfordmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ashmolean.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ashridgehouse.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.ashwellmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://theassayoffice.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.tameside.gov.uk/astleycheetham' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://lancashireminingmuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://chorley.gov.uk/Pages/AtoZ/Astley-Hall.aspx' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.birminghammuseums.org.uk/aston' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.amht.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.athelhampton.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.athelstanmuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitscotland.com/info/see-do/atholl-country-life-museum-p1672101' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.theatkinson.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/attingham-park' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://atwellwilson.org.uk/index.html' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.auchindrain.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.aucklandproject.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.english-heritage.org.uk/visit/places/audley-end-house-and-gardens/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.fermanaghlakelands.com/Aughakillymaude-Mummers-Centre-Derrylin-Enniskillen-P14167' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.edlc.co.uk/heritage-arts/auld-kirk-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'no_resource' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.avingtonpark.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.avonvalleyrailway.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://avoncroft.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.avroheritagemuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.devonmuseums.net/Axe-Valley-Heritage-Museum/Devon-Museums/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://axminsterheritage.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://ilikemuseums.com/museums/73890' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.aylshamheritage.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.tracesofwar.com/sights/929/Ayrshire-Yeomanry-Museum.htm' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.sholland.gov.uk/article/5262/Ayscoughfee-Hall-Museum-and-Gardens' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nts.org.uk/visit/places/bachelors-club' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.bacupnaturalhistorysociety.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.nationaltrust.org.uk/baddesley-clinton' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.kirklees.gov.uk/bagshawmuseum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://bailiffgatemuseum.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://eastayrshireleisure.com/culture/the-baird-institute/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://captainbeany.com/baked-bean-museum-of-excellence/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.oldhousemuseum.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.baldockhistory.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://discovernorthernireland.com/things-to-do/ballance-house-p694731' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.ballindallochcastle.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://discovernorthernireland.com/things-to-do/ballycastle-museum-p674981' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.causewaycoastandglens.gov.uk/see-do/arts_museums/museums-services/ballymoney-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.balmoralcastle.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.bamburghcastle.com/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.tracesofwar.com/sights/1893/Bamburgh-Castle-Aviation-Artefacts-Museum.htm' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.banburymuseum.org/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.visitbanchory.com/things-to-do/local-attractions/banchory-museum/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.bancroftmill.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://www.bphsmob.org.uk/pages/museum-of-banff' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.bangor.ac.uk/community/museum.php.en' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.bankofengland.co.uk/museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://museums.calderdale.gov.uk/visit/bankfield-museum' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://bannvalleyheritage.wixsite.com/bannvalleyheritage' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.hrp.org.uk/banqueting-house/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.wolverhamptonart.org.uk/visit/bantock/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.bar-convent.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.tate.org.uk/visit/tate-st-ives/barbara-hepworth-museum-and-sculpture-garden' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'http://barber.org.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://barleyhall.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
#         and p.url = 'https://www.barleylands.co.uk/' and a.attrib_name = 'all_text';
# select url, a.page_id, attrib_name, attrib_val from websites.web_pages_dump_20210614 p, websites.web_pages_dump_20210614_attr a where a.page_id = p.page_id
# ...
# 2               1        Main        Main   PROPN    False
# 3               1     Content     Content   PROPN    False
# 4               1    Greeters    Greeters   PROPN    False
# ...           ...         ...         ...     ...      ...
# 1143          127  Accessible  Accessible   PROPN    False
# 1144          127         Get         get     AUX     True
# 1145          127          in          in     ADP     True
# 1146          127       touch       touch    NOUN    False
# 1147          127     Weather     weather    NOUN    False
#
# [1148 rows x 5 columns], 'mm.domus.SW133':       sentence_id       token       lemma pos_tag  is_stop
# 0               1        Skip        Skip    NOUN    False
# 1               1        over        over     ADP     True
# 2               1        main        main     ADJ    False
# 3               1  navigation  navigation    NOUN    False
# 4               1         Log         Log   PROPN    False
# ...           ...         ...         ...     ...      ...
# 1082          143       place       place    NOUN    False
# 1083          143          \n          \n   SPACE    False
# 1084          143        here        here     ADV     True
# 1085          143          \n          \n   SPACE    False
# 1086          143           .           .   PUNCT    False
#
# [1087 rows x 5 columns], 'mm.domus.SE380':       sentence_id      token      lemma pos_tag  is_stop
# 0               1       skip       skip    NOUN    False
# 1               1         to         to    PART     True
# 2               1    content    content    VERB    False
# 3               1      Study      Study   PROPN    False
# 4               1         at         at     ADP     True
# ...           ...        ...        ...     ...      ...
# 1241           99        ...        ...   PUNCT    False
# 1242          100      About      about     ADP     True
# 1243          100   research   research    NOUN    False
# 1244          100         at         at     ADP     True
# 1245          100  Cambridge  Cambridge   PROPN    False
#
# [1246 rows x 5 columns], 'mm.domus.SC308':      sentence_id    token    lemma pos_tag  is_stop
# 0              1     Skip     Skip    NOUN    False
# 1              1       to       to     ADP     True
# 2              1     main     main     ADJ    False
# 3              1  content  content    NOUN    False
# 4              1     This     this     DET     True
# ..           ...      ...      ...     ...      ...
# 576           60  Lothian  Lothian   PROPN    False
# 577           60  Council  Council   PROPN    False
# 578           60  Powered    power    VERB    False
# 579           60       by       by     ADP     True
# 580           60     GOSS     GOSS   PROPN    False
#
# [581 rows x 5 columns], 'mm.domus.NW144':      sentence_id       token       lemma pos_tag  is_stop
# 0              1        Skip        Skip    NOUN    False
# 1              1          to          to     ADP     True
# 2              1  navigation  navigation    NOUN    False
# 3              1           |           |   PROPN    False
# 4              1        Skip        Skip   PROPN    False
# ..           ...         ...         ...     ...      ...
# 847           82          \n          \n   SPACE    False
# 848           82     Listing        list    VERB    False
# 849           82          \n          \n   SPACE    False
# 850           82        test        test    NOUN    False
# 851           82       parts        part    NOUN    False
#
# [852 rows x 5 columns], 'mm.wiki.314':      sentence_id      token      lemma pos_tag  is_stop
# 0              1        Car        car    NOUN    False
# 1              1    History    history    NOUN    False
# 2              1  Guardians  Guardians   PROPN    False
# 3              1         of         of     ADP     True
# 4              1     Honour     Honour   PROPN    False
# ..           ...        ...        ...     ...      ...
# 603           33        Off        Off   PROPN     True
# 604           33       Save       Save   PROPN    False
# 605           33   Settings    setting    NOUN    False
# 606           33     Accept     Accept   PROPN    False
# 607           33        All        all     DET     True
#
# [608 rows x 5 columns], 'mm.domus.SE220':       sentence_id    token    lemma pos_tag  is_stop
# 0               1     Skip     Skip    NOUN    False
# 1               1       to       to     ADP     True
# 2               1     main     main     ADJ    False
# 3               1  content  content    NOUN    False
# 4               1   Search   Search   PROPN    False
# ...           ...      ...      ...     ...      ...
# 2354          223        !        !   PUNCT    False
# 2355          224    Loans    Loans   PROPN    False
# 2356          224    Boxes    Boxes   PROPN    False
# 2357          224     News     News   PROPN    False
# 2358          224  Contact  Contact   PROPN    False
#
# [2359 rows x 5 columns], 'mm.domus.SE541':       sentence_id     token     lemma pos_tag  is_stop
# 0               1      Skip      Skip    NOUN    False
# 1               1        to        to    PART     True
# 2               1   content   content    NOUN    False
# 3               1        Go        go    VERB     True
# 4               1        to        to    PART     True
# ...           ...       ...       ...     ...      ...
# 3315          230         /         /     SYM    False
# 3316          230  register  register    VERB    False
# 3317          230      Back      back     ADV     True
# 3318          230        to        to     ADP     True
# 3319          230       top       top    NOUN     True
#
# [3320 rows x 5 columns], 'mm.domus.SE254':       sentence_id    token    lemma pos_tag  is_stop
# 0               1     Skip     Skip    NOUN    False
# 1               1       to       to     ADP     True
# 2               1     main     main     ADJ    False
# 3               1  content  content    NOUN    False
# 4               1   Search   Search   PROPN    False
# ...           ...      ...      ...     ...      ...
# 2177          205        !        !   PUNCT    False
# 2178          206    Loans    Loans   PROPN    False
# 2179          206    Boxes    Boxes   PROPN    False
# 2180          206     News     News   PROPN    False
# 2181          206  Contact  Contact   PROPN    False
#
# [2182 rows x 5 columns], 'mm.aim.1326':      sentence_id       token       lemma pos_tag  is_stop
# 0              1        Skip        Skip    NOUN    False
# 1              1          to          to     ADP     True
# 2              1        main        main     ADJ    False
# 3              1     content     content    NOUN    False
# 4              2  Winchester  Winchester   PROPN    False
# ..           ...         ...         ...     ...      ...
# 413           47      Policy      Policy   PROPN    False
# 414           47          \n          \n   SPACE    False
# 415           47           |           |     NUM    False
# 416           47          \n          \n   SPACE    False
# 417           47     Sitemap     Sitemap   PROPN    False
#
# [418 rows x 5 columns], 'mm.fcm.274':       sentence_id                   token                   lemma pos_tag  \
# 0               1                    Open                    open     ADJ
# 1               1                 Tuesday                 Tuesday   PROPN
# 2               1                      to                      to     ADP
# 3               1                  Sunday                  Sunday   PROPN
# 4               1                       -                       -   PUNCT
# ...           ...                     ...                     ...     ...
# 2829          237  info@wingsmuseum.co.uk  info@wingsmuseum.co.uk   PROPN
# 2830          238                Facebook                Facebook   PROPN
# 2831          238                 Twitter                 Twitter   PROPN
# 2832          238               Instagram               Instagram   PROPN
# 2833          238                Podcasts                Podcasts   PROPN
#
#       is_stop
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# ...       ...
# 2829    False
# 2830    False
# 2831    False
# 2832    False
# 2833    False
#
# [2834 rows x 5 columns], 'mm.hha.069':      sentence_id       token       lemma pos_tag  is_stop
# 0              1        This        this     DET     True
# 1              1     website     website    NOUN    False
# 2              1    requires     require    VERB    False
# 3              1  javascript  javascript   PROPN    False
# 4              1          to          to    PART     True
# ..           ...         ...         ...     ...      ...
# 261           16      Accept      Accept   PROPN    False
# 262           16           &           &   CCONJ    False
# 263           16    Continue    Continue   PROPN    False
# 264           17        View        View   PROPN    False
# 265           17     details      detail    NOUN    False
#
# [266 rows x 5 columns], 'mm.domus.WM013':      sentence_id          token          lemma pos_tag  is_stop
# 0              1  Wolverhampton  Wolverhampton   PROPN    False
# 1              1            Art            Art   PROPN    False
# 2              1        Gallery        Gallery   PROPN    False
# 3              1  Wolverhampton  Wolverhampton   PROPN    False
# 4              1           City           City   PROPN    False
# ..           ...            ...            ...     ...      ...
# 588           54        website        website    NOUN    False
# 589           54              .              .   PUNCT    False
# 590           55           SAVE           SAVE   PROPN    False
# 591           55              &              &   CCONJ    False
# 592           55         ACCEPT         ACCEPT   PROPN    False
#
# [593 rows x 5 columns], 'mm.domus.EM110':      sentence_id    token    lemma pos_tag  is_stop
# 0              1     Skip     Skip    NOUN    False
# 1              1       to       to    PART     True
# 2              1  content  content    VERB    False
# 3              1      The      the     DET     True
# 4              1   Museum   Museum   PROPN    False
# ..           ...      ...      ...     ...      ...
# 540           62  Website  website    NOUN    False
# 541           62       by       by     ADP     True
# 542           62       \n       \n   SPACE    False
# 543           62   Craven   Craven   PROPN    False
# 544           62  Digital  Digital   PROPN    False
#
# [545 rows x 5 columns], 'mm.domus.EM089':       sentence_id     token     lemma pos_tag  is_stop
# 0               1      Skip      Skip    NOUN    False
# 1               1        to        to    PART     True
# 2               1   content   content    NOUN    False
# 3               1        Go        go    VERB     True
# 4               1        to        to    PART     True
# ...           ...       ...       ...     ...      ...
# 2670          191         /         /     SYM    False
# 2671          191  register  register    VERB    False
# 2672          191      Back      back     ADV     True
# 2673          191        to        to     ADP     True
# 2674          191       top       top    NOUN     True
#
# [2675 rows x 5 columns], 'mm.domus.WM010':       sentence_id      token      lemma pos_tag  is_stop
# 0               1       Skip       Skip    NOUN    False
# 1               1         to         to    PART     True
# 2               1    content    content    VERB    False
# 3               1   Facebook   Facebook   PROPN    False
# 4               1         \n         \n   SPACE    False
# ...           ...        ...        ...     ...      ...
# 1441          135         \n         \n   SPACE    False
# 1442          135  Instagram  Instagram   PROPN    False
# 1443          135         Go         go    VERB     True
# 1444          135         to         to     ADP     True
# 1445          135        Top        top    NOUN     True
#
# [1446 rows x 5 columns], 'mm.domus.WM027':       sentence_id      token      lemma pos_tag  is_stop
# 0               1       Skip       Skip    NOUN    False
# 1               1         to         to    PART     True
# 2               1    content    content    VERB    False
# 3               1   Facebook   Facebook   PROPN    False
# 4               1         \n         \n   SPACE    False
# ...           ...        ...        ...     ...      ...
# 2360          202         \n         \n   SPACE    False
# 2361          202  Instagram  Instagram   PROPN    False
# 2362          202         Go         go    VERB     True
# 2363          202         to         to     ADP     True
# 2364          202        Top        top    NOUN     True
#
# [2365 rows x 5 columns], 'mm.musa.394':      sentence_id token lemma pos_tag  is_stop
# 0              1  Home  home    NOUN    False
# 1              1    \n    \n   SPACE    False
# 2              2  What  what    PRON     True
# 3              2    's    be     AUX     True
# 4              2    On    on     ADP     True
# ..           ...   ...   ...     ...      ...
# 730           73    to    to    PART     True
# 731           73  find  find    VERB    False
# 732           73   out   out     ADP     True
# 733           73  more  more     ADJ     True
# 734           73     .     .   PUNCT    False
#
# [735 rows x 5 columns], 'mm.domus.SE382':       sentence_id      token      lemma pos_tag  is_stop
# 0               1       skip       skip    NOUN    False
# 1               1         to         to    PART     True
# 2               1    content    content    VERB    False
# 3               1      Study      Study   PROPN    False
# 4               1         at         at     ADP     True
# ...           ...        ...        ...     ...      ...
# 1968          207        ...        ...   PUNCT    False
# 1969          208      About      about     ADP     True
# 1970          208   research   research    NOUN    False
# 1971          208         at         at     ADP     True
# 1972          208  Cambridge  Cambridge   PROPN    False
#
# [1973 rows x 5 columns], 'mm.New.13':      sentence_id    token    lemma pos_tag  is_stop
# 0              1     Home     home    NOUN    False
# 1              1       \n       \n   SPACE    False
# 2              1    About    about     ADP     True
# 3              1       us   -PRON-    PRON     True
# 4              1       \n       \n   SPACE    False
# ..           ...      ...      ...     ...      ...
# 916           89        I   -PRON-    PRON     True
# 917           89    agree    agree    VERB    False
# 918           89       \n       \n   SPACE    False
# 919           90        I   -PRON-    PRON     True
# 920           90  decline  decline    VERB    False
#
# [921 rows x 5 columns], 'mm.misc.231':       sentence_id          token          lemma pos_tag  is_stop
# 0               1           Jump           jump    VERB    False
# 1               1             to             to     ADP     True
# 2               1           main           main     ADJ    False
# 3               1        content        content    NOUN    False
# 4               1           Jump           jump    NOUN    False
# ...           ...            ...            ...     ...      ...
# 1114          101     protection     protection    NOUN    False
# 1115          101        Cookies         cookie    NOUN    False
# 1116          101  Accessibility  Accessibility   PROPN    False
# 1117          101           Site           Site   PROPN    False
# 1118          101            map            map    NOUN    False
#
# [1119 rows x 5 columns], 'mm.aim.1335':       sentence_id     token     lemma pos_tag  is_stop
# 0               1     Phone     phone    NOUN    False
# 1               1         :         :   PUNCT    False
# 2               1     01282     01282     NUM    False
# 3               1    788290    788290     NUM    False
# 4               2      Home      Home   PROPN    False
# ...           ...       ...       ...     ...      ...
# 1192           89       our    -PRON-     DET     True
# 1193           89     pages      page    NOUN    False
# 1194           89         .         .   PUNCT    False
# 1195           90    Cookie    Cookie   PROPN    False
# 1196           90  Settings  Settings   PROPN    False
#
# [1197 rows x 5 columns]}

# %% [markdown]
# For each mus id, sessionid
# get all urls()
# for each url:
# get attribute all text
#
# on attribute all text call tokenization
# produce df

# %% [markdown]
# End of notebook
